# %% [markdown]
# # Computer Vision Contours

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Contours

# %%
# Have a look at the image below
color_coins = cv2.imread('img/coins5.jpg', cv2.IMREAD_COLOR)
rgb_coins = cv2.cvtColor(color_coins,cv2.COLOR_BGR2RGB)

plt.figure(figsize = (12,8))
plt.imshow(rgb_coins);

# %%
# Convert the image above to grayscale
gray = cv2.cvtColor(rgb_coins,cv2.COLOR_BGR2GRAY)


# Apply some gaussian blur to it (try differente size kernels)
gauss = cv2.GaussianBlur(gray,(5,5),0,0 )


# Apply Canny to find edges and display the image 
canny = cv2.Canny(gauss,240,255)
cv2.imshow('Canny',canny)
cv2.waitKey(0)
# Out:
# -1

# %%
# Now find the contours on the image where you applied canny as well as in the grayscale image
# Draw the contours on the images (or better yet on copies of the images)
# Display the images, how does it look like?
# .findContours(image, mode, method[, contours[, hierarchy[, offset]]]) -> contours, hierarchy
contours,h = cv2.findContours(canny,cv2.RETR_LIST,cv2.CHAIN_APPROX_NONE) 
print(contours) 
# drawContours(image, contours, contourIdx, color[, thickness[, lineType[, hierarchy[, maxLevel[, offset]]]]]) -> image
new_img = cv2.drawContours(canny,contours,-1,(100,100,100),3)
cv2.imshow('Contours',canny)
cv2.waitKey(0)
# Out:
# [array([[[500, 697]],
#
#        [[499, 698]],
#
#        [[498, 699]],
#
#        [[497, 700]],
#
#        [[496, 700]],
#
#        [[495, 701]],
#
#        [[494, 702]],
#
#        [[493, 702]],
#
#        [[492, 703]],
#
#        [[491, 704]],
#
#        [[490, 705]],
#
#        [[489, 705]],
#
#        [[488, 706]],
#
#        [[487, 706]],
#
#        [[486, 707]],
#
#        [[485, 708]],
#
#        [[486, 707]],
#
#        [[487, 707]],
#
#        [[488, 706]],
#
#        [[489, 705]],
#
#        [[490, 705]],
#
#        [[491, 704]],
#
#        [[492, 703]],
#
#        [[493, 703]],
#
#        [[494, 702]],
#
#        [[495, 701]],
#
#        [[496, 701]],
#
#        [[497, 700]],
#
#        [[498, 699]],
#
#        [[499, 698]]], dtype=int32), array([[[503, 695]]], dtype=int32), array([[[510, 689]],
#
#        [[509, 690]]], dtype=int32), array([[[522, 676]],
#
#        [[521, 677]],
#
#        [[520, 678]],
#
#        [[519, 679]],
#
#        [[518, 680]],
#
#        [[517, 681]],
#
#        [[517, 682]],
#
#        [[516, 683]],
#
#        [[515, 684]],
#
#        [[516, 683]],
#
#        [[517, 682]],
#
#        [[518, 681]],
#
#        [[519, 680]],
#
#        [[519, 679]],
#
#        [[520, 678]],
#
#        [[521, 677]]], dtype=int32), array([[[525, 672]],
#
#        [[524, 673]]], dtype=int32), array([[[527, 669]],
#
#        [[526, 670]]], dtype=int32), array([[[307, 645]],
#
#        [[308, 646]],
#
#        [[308, 647]],
#
#        [[309, 648]],
#
#        [[309, 649]],
#
#        [[310, 650]],
#
#        [[310, 651]],
#
#        [[311, 652]],
#
#        [[311, 653]],
#
#        [[312, 654]],
#
#        [[313, 655]],
#
#        [[313, 656]],
#
#        [[314, 657]],
#
#        [[314, 658]],
#
#        [[315, 659]],
#
#        [[316, 660]],
#
#        [[316, 661]],
#
#        [[316, 660]],
#
#        [[315, 659]],
#
#        [[315, 658]],
#
#        [[314, 657]],
#
#        [[313, 656]],
#
#        [[313, 655]],
#
#        [[312, 654]],
#
#        [[311, 653]],
#
#        [[311, 652]],
#
#        [[310, 651]],
#
#        [[310, 650]],
#
#        [[309, 649]],
#
#        [[309, 648]],
#
#        [[308, 647]],
#
#        [[308, 646]]], dtype=int32), array([[[149, 500]],
#
#        [[150, 499]],
#
#        [[151, 499]],
#
#        ...,
#
#        [[146, 500]],
#
#        [[147, 500]],
#
#        [[148, 500]]], dtype=int32), array([[[150, 499]],
#
#        [[149, 500]],
#
#        [[148, 500]],
#
#        ...,
#
#        [[153, 499]],
#
#        [[152, 499]],
#
#        [[151, 499]]], dtype=int32), array([[[656, 478]],
#
#        [[657, 477]],
#
#        [[658, 477]],
#
#        [[659, 477]],
#
#        [[660, 477]],
#
#        [[661, 477]],
#
#        [[662, 477]],
#
#        [[663, 477]],
#
#        [[664, 477]],
#
#        [[665, 477]],
#
#        [[666, 477]],
#
#        [[667, 477]],
#
#        [[668, 477]],
#
#        [[669, 477]],
#
#        [[670, 477]],
#
#        [[671, 477]],
#
#        [[672, 478]],
#
#        [[673, 478]],
#
#        [[674, 478]],
#
#        [[675, 478]],
#
#        [[676, 478]],
#
#        [[677, 478]],
#
#        [[678, 478]],
#
#        [[679, 479]],
#
#        [[680, 479]],
#
#        [[681, 479]],
#
#        [[682, 479]],
#
#        [[683, 479]],
#
#        [[684, 480]],
#
#        [[685, 480]],
#
#        [[686, 480]],
#
#        [[687, 480]],
#
#        [[688, 481]],
#
#        [[689, 481]],
#
#        [[690, 481]],
#
#        [[691, 482]],
#
#        [[692, 482]],
#
#        [[693, 482]],
#
#        [[694, 483]],
#
#        [[695, 483]],
#
#        [[696, 483]],
#
#        [[697, 484]],
#
#        [[698, 484]],
#
#        [[699, 485]],
#
#        [[700, 485]],
#
#        [[701, 486]],
#
#        [[702, 486]],
#
#        [[703, 486]],
#
#        [[704, 487]],
#
#        [[705, 488]],
#
#        [[706, 488]],
#
#        [[707, 489]],
#
#        [[708, 489]],
#
#        [[709, 490]],
#
#        [[710, 490]],
#
#        [[711, 491]],
#
#        [[712, 491]],
#
#        [[713, 492]],
#
#        [[714, 493]],
#
#        [[715, 494]],
#
#        [[716, 494]],
#
#        [[717, 495]],
#
#        [[718, 496]],
#
#        [[719, 496]],
#
#        [[720, 497]],
#
#        [[721, 498]],
#
#        [[722, 499]],
#
#        [[723, 500]],
#
#        [[724, 501]],
#
#        [[725, 501]],
#
#        [[726, 502]],
#
#        [[727, 503]],
#
#        [[728, 504]],
#
#        [[729, 505]],
#
#        [[730, 506]],
#
#        [[731, 507]],
#
#        [[732, 508]],
#
#        [[733, 509]],
#
#        [[733, 510]],
#
#        [[734, 511]],
#
#        [[735, 512]],
#
#        [[736, 513]],
#
#        [[737, 514]],
#
#        [[737, 515]],
#
#        [[738, 516]],
#
#        [[739, 517]],
#
#        [[739, 518]],
#
#        [[740, 519]],
#
#        [[741, 520]],
#
#        [[741, 521]],
#
#        [[742, 522]],
#
#        [[743, 523]],
#
#        [[743, 524]],
#
#        [[744, 525]],
#
#        [[745, 526]],
#
#        [[745, 527]],
#
#        [[746, 528]],
#
#        [[747, 529]],
#
#        [[747, 530]],
#
#        [[748, 531]],
#
#        [[748, 532]],
#
#        [[749, 533]],
#
#        [[749, 534]],
#
#        [[750, 535]],
#
#        [[750, 536]],
#
#        [[750, 537]],
#
#        [[751, 538]],
#
#        [[751, 539]],
#
#        [[752, 540]],
#
#        [[752, 541]],
#
#        [[753, 542]],
#
#        [[753, 543]],
#
#        [[753, 544]],
#
#        [[753, 545]],
#
#        [[754, 546]],
#
#        [[754, 547]],
#
#        [[754, 548]],
#
#        [[755, 549]],
#
#        [[755, 550]],
#
#        [[755, 551]],
#
#        [[755, 552]],
#
#        [[755, 553]],
#
#        [[756, 554]],
#
#        [[756, 555]],
#
#        [[756, 556]],
#
#        [[756, 557]],
#
#        [[756, 558]],
#
#        [[757, 559]],
#
#        [[757, 560]],
#
#        [[757, 561]],
#
#        [[757, 562]],
#
#        [[757, 563]],
#
#        [[757, 564]],
#
#        [[757, 565]],
#
#        [[757, 566]],
#
#        [[757, 567]],
#
#        [[757, 568]],
#
#        [[757, 569]],
#
#        [[757, 570]],
#
#        [[757, 571]],
#
#        [[757, 572]],
#
#        [[757, 573]],
#
#        [[757, 574]],
#
#        [[757, 575]],
#
#        [[757, 576]],
#
#        [[757, 577]],
#
#        [[757, 578]],
#
#        [[757, 579]],
#
#        [[757, 580]],
#
#        [[756, 581]],
#
#        [[756, 582]],
#
#        [[756, 583]],
#
#        [[756, 584]],
#
#        [[756, 585]],
#
#        [[756, 586]],
#
#        [[755, 587]],
#
#        [[755, 588]],
#
#        [[755, 589]],
#
#        [[755, 590]],
#
#        [[754, 591]],
#
#        [[754, 592]],
#
#        [[754, 593]],
#
#        [[754, 594]],
#
#        [[753, 595]],
#
#        [[753, 596]],
#
#        [[753, 597]],
#
#        [[752, 598]],
#
#        [[752, 599]],
#
#        [[752, 600]],
#
#        [[751, 601]],
#
#        [[751, 602]],
#
#        [[750, 603]],
#
#        [[750, 604]],
#
#        [[749, 605]],
#
#        [[749, 606]],
#
#        [[748, 607]],
#
#        [[748, 608]],
#
#        [[747, 609]],
#
#        [[747, 610]],
#
#        [[746, 611]],
#
#        [[745, 612]],
#
#        [[745, 613]],
#
#        [[744, 614]],
#
#        [[743, 615]],
#
#        [[743, 616]],
#
#        [[742, 617]],
#
#        [[741, 618]],
#
#        [[740, 619]],
#
#        [[740, 620]],
#
#        [[739, 621]],
#
#        [[738, 622]],
#
#        [[737, 623]],
#
#        [[736, 624]],
#
#        [[735, 625]],
#
#        [[734, 626]],
#
#        [[733, 627]],
#
#        [[732, 628]],
#
#        [[731, 629]],
#
#        [[730, 630]],
#
#        [[729, 630]],
#
#        [[728, 631]],
#
#        [[727, 632]],
#
#        [[726, 633]],
#
#        [[725, 633]],
#
#        [[724, 634]],
#
#        [[723, 635]],
#
#        [[722, 636]],
#
#        [[721, 636]],
#
#        [[720, 637]],
#
#        [[719, 637]],
#
#        [[718, 638]],
#
#        [[717, 638]],
#
#        [[716, 639]],
#
#        [[715, 639]],
#
#        [[714, 640]],
#
#        [[713, 640]],
#
#        [[712, 641]],
#
#        [[711, 641]],
#
#        [[710, 642]],
#
#        [[709, 642]],
#
#        [[708, 643]],
#
#        [[707, 643]],
#
#        [[706, 643]],
#
#        [[705, 644]],
#
#        [[704, 644]],
#
#        [[703, 644]],
#
#        [[702, 645]],
#
#        [[701, 645]],
#
#        [[700, 645]],
#
#        [[699, 645]],
#
#        [[698, 646]],
#
#        [[697, 646]],
#
#        [[696, 646]],
#
#        [[695, 646]],
#
#        [[694, 646]],
#
#        [[693, 647]],
#
#        [[692, 647]],
#
#        [[691, 647]],
#
#        [[690, 647]],
#
#        [[689, 647]],
#
#        [[688, 647]],
#
#        [[687, 647]],
#
#        [[686, 648]],
#
#        [[685, 648]],
#
#        [[684, 648]],
#
#        [[683, 648]],
#
#        [[682, 648]],
#
#        [[681, 648]],
#
#        [[680, 648]],
#
#        [[679, 648]],
#
#        [[678, 648]],
#
#        [[677, 648]],
#
#        [[676, 648]],
#
#        [[675, 648]],
#
#        [[674, 648]],
#
#        [[673, 648]],
#
#        [[672, 648]],
#
#        [[671, 648]],
#
#        [[670, 648]],
#
#        [[669, 648]],
#
#        [[668, 648]],
#
#        [[667, 648]],
#
#        [[666, 647]],
#
#        [[665, 647]],
#
#        [[664, 647]],
#
#        [[663, 647]],
#
#        [[662, 647]],
#
#        [[661, 647]],
#
#        [[660, 647]],
#
#        [[659, 646]],
#
#        [[658, 646]],
#
#        [[657, 646]],
#
#        [[656, 646]],
#
#        [[655, 645]],
#
#        [[654, 645]],
#
#        [[653, 645]],
#
#        [[652, 645]],
#
#        [[651, 644]],
#
#        [[650, 644]],
#
#        [[649, 644]],
#
#        [[648, 643]],
#
#        [[647, 643]],
#
#        [[646, 643]],
#
#        [[645, 642]],
#
#        [[644, 642]],
#
#        [[643, 641]],
#
#        [[642, 641]],
#
#        [[641, 640]],
#
#        [[640, 640]],
#
#        [[639, 639]],
#
#        [[638, 639]],
#
#        [[637, 638]],
#
#        [[636, 638]],
#
#        [[635, 637]],
#
#        [[634, 637]],
#
#        [[633, 636]],
#
#        [[632, 636]],
#
#        [[631, 635]],
#
#        [[630, 634]],
#
#        [[629, 634]],
#
#        [[628, 633]],
#
#        [[627, 633]],
#
#        [[626, 632]],
#
#        [[625, 631]],
#
#        [[624, 630]],
#
#        [[623, 630]],
#
#        [[622, 629]],
#
#        [[621, 628]],
#
#        [[620, 627]],
#
#        [[619, 627]],
#
#        [[618, 626]],
#
#        [[617, 625]],
#
#        [[616, 624]],
#
#        [[615, 623]],
#
#        [[614, 622]],
#
#        [[613, 621]],
#
#        [[612, 620]],
#
#        [[611, 619]],
#
#        [[610, 618]],
#
#        [[609, 617]],
#
#        [[608, 616]],
#
#        [[607, 615]],
#
#        [[606, 614]],
#
#        [[605, 613]],
#
#        [[605, 612]],
#
#        [[604, 611]],
#
#        [[603, 610]],
#
#        [[602, 609]],
#
#        [[602, 608]],
#
#        [[601, 607]],
#
#        [[600, 606]],
#
#        [[600, 605]],
#
#        [[599, 604]],
#
#        [[598, 603]],
#
#        [[598, 602]],
#
#        [[597, 601]],
#
#        [[597, 600]],
#
#        [[596, 599]],
#
#        [[595, 598]],
#
#        [[595, 597]],
#
#        [[594, 596]],
#
#        [[594, 595]],
#
#        [[593, 594]],
#
#        [[593, 593]],
#
#        [[592, 592]],
#
#        [[592, 591]],
#
#        [[592, 590]],
#
#        [[591, 589]],
#
#        [[591, 588]],
#
#        [[590, 587]],
#
#        [[590, 586]],
#
#        [[589, 585]],
#
#        [[589, 584]],
#
#        [[589, 583]],
#
#        [[588, 582]],
#
#        [[588, 581]],
#
#        [[588, 580]],
#
#        [[588, 579]],
#
#        [[587, 578]],
#
#        [[587, 577]],
#
#        [[587, 576]],
#
#        [[587, 575]],
#
#        [[586, 574]],
#
#        [[586, 573]],
#
#        [[586, 572]],
#
#        [[586, 571]],
#
#        [[586, 570]],
#
#        [[585, 569]],
#
#        [[585, 568]],
#
#        [[585, 567]],
#
#        [[585, 566]],
#
#        [[585, 565]],
#
#        [[585, 564]],
#
#        [[585, 563]],
#
#        [[585, 562]],
#
#        [[585, 561]],
#
#        [[585, 560]],
#
#        [[585, 559]],
#
#        [[585, 558]],
#
#        [[584, 557]],
#
#        [[584, 556]],
#
#        [[584, 555]],
#
#        [[585, 554]],
#
#        [[585, 553]],
#
#        [[585, 552]],
#
#        [[585, 551]],
#
#        [[585, 550]],
#
#        [[585, 549]],
#
#        [[585, 548]],
#
#        [[585, 547]],
#
#        [[585, 546]],
#
#        [[585, 545]],
#
#        [[585, 544]],
#
#        [[586, 543]],
#
#        [[586, 542]],
#
#        [[586, 541]],
#
#        [[586, 540]],
#
#        [[586, 539]],
#
#        [[587, 538]],
#
#        [[587, 537]],
#
#        [[587, 536]],
#
#        [[587, 535]],
#
#        [[588, 534]],
#
#        [[588, 533]],
#
#        [[588, 532]],
#
#        [[589, 531]],
#
#        [[589, 530]],
#
#        [[589, 529]],
#
#        [[590, 528]],
#
#        [[590, 527]],
#
#        [[590, 526]],
#
#        [[591, 525]],
#
#        [[591, 524]],
#
#        [[592, 523]],
#
#        [[592, 522]],
#
#        [[593, 521]],
#
#        [[593, 520]],
#
#        [[594, 519]],
#
#        [[595, 518]],
#
#        [[595, 517]],
#
#        [[596, 516]],
#
#        [[596, 515]],
#
#        [[597, 514]],
#
#        [[598, 513]],
#
#        [[598, 512]],
#
#        [[599, 511]],
#
#        [[600, 510]],
#
#        [[601, 509]],
#
#        [[601, 508]],
#
#        [[602, 507]],
#
#        [[603, 506]],
#
#        [[604, 505]],
#
#        [[605, 504]],
#
#        [[606, 503]],
#
#        [[607, 502]],
#
#        [[608, 501]],
#
#        [[609, 500]],
#
#        [[610, 499]],
#
#        [[611, 498]],
#
#        [[612, 497]],
#
#        [[613, 496]],
#
#        [[614, 495]],
#
#        [[615, 494]],
#
#        [[616, 494]],
#
#        [[617, 493]],
#
#        [[618, 492]],
#
#        [[619, 491]],
#
#        [[620, 491]],
#
#        [[621, 490]],
#
#        [[622, 489]],
#
#        [[623, 489]],
#
#        [[624, 488]],
#
#        [[625, 488]],
#
#        [[626, 487]],
#
#        [[627, 486]],
#
#        [[628, 486]],
#
#        [[629, 485]],
#
#        [[630, 485]],
#
#        [[631, 484]],
#
#        [[632, 484]],
#
#        [[633, 483]],
#
#        [[634, 483]],
#
#        [[635, 483]],
#
#        [[636, 482]],
#
#        [[637, 482]],
#
#        [[638, 481]],
#
#        [[639, 481]],
#
#        [[640, 481]],
#
#        [[641, 480]],
#
#        [[642, 480]],
#
#        [[643, 480]],
#
#        [[644, 480]],
#
#        [[645, 479]],
#
#        [[646, 479]],
#
#        [[647, 479]],
#
#        [[648, 479]],
#
#        [[649, 479]],
#
#        [[650, 478]],
#
#        [[651, 478]],
#
#        [[652, 478]],
#
#        [[653, 478]],
#
#        [[654, 478]],
#
#        [[655, 478]]], dtype=int32), array([[[657, 477]],
#
#        [[656, 478]],
#
#        [[655, 478]],
#
#        [[654, 478]],
#
#        [[653, 478]],
#
#        [[652, 478]],
#
#        [[651, 478]],
#
#        [[650, 478]],
#
#        [[649, 479]],
#
#        [[648, 479]],
#
#        [[647, 479]],
#
#        [[646, 479]],
#
#        [[645, 479]],
#
#        [[644, 480]],
#
#        [[643, 480]],
#
#        [[642, 480]],
#
#        [[641, 480]],
#
#        [[640, 481]],
#
#        [[639, 481]],
#
#        [[638, 481]],
#
#        [[637, 482]],
#
#        [[636, 482]],
#
#        [[635, 483]],
#
#        [[634, 483]],
#
#        [[633, 483]],
#
#        [[632, 484]],
#
#        [[631, 484]],
#
#        [[630, 484]],
#
#        [[629, 485]],
#
#        [[628, 485]],
#
#        [[627, 486]],
#
#        [[626, 486]],
#
#        [[625, 487]],
#
#        [[624, 488]],
#
#        [[623, 488]],
#
#        [[622, 489]],
#
#        [[621, 489]],
#
#        [[620, 490]],
#
#        [[619, 491]],
#
#        [[618, 491]],
#
#        [[617, 492]],
#
#        [[616, 493]],
#
#        [[615, 494]],
#
#        [[614, 494]],
#
#        [[613, 495]],
#
#        [[612, 496]],
#
#        [[611, 497]],
#
#        [[610, 498]],
#
#        [[609, 499]],
#
#        [[608, 500]],
#
#        [[607, 501]],
#
#        [[606, 502]],
#
#        [[605, 503]],
#
#        [[604, 504]],
#
#        [[603, 505]],
#
#        [[602, 506]],
#
#        [[601, 507]],
#
#        [[601, 508]],
#
#        [[600, 509]],
#
#        [[599, 510]],
#
#        [[598, 511]],
#
#        [[598, 512]],
#
#        [[597, 513]],
#
#        [[596, 514]],
#
#        [[596, 515]],
#
#        [[595, 516]],
#
#        [[595, 517]],
#
#        [[594, 518]],
#
#        [[593, 519]],
#
#        [[593, 520]],
#
#        [[592, 521]],
#
#        [[592, 522]],
#
#        [[591, 523]],
#
#        [[591, 524]],
#
#        [[591, 525]],
#
#        [[590, 526]],
#
#        [[590, 527]],
#
#        [[590, 528]],
#
#        [[589, 529]],
#
#        [[589, 530]],
#
#        [[589, 531]],
#
#        [[588, 532]],
#
#        [[588, 533]],
#
#        [[588, 534]],
#
#        [[587, 535]],
#
#        [[587, 536]],
#
#        [[587, 537]],
#
#        [[587, 538]],
#
#        [[586, 539]],
#
#        [[586, 540]],
#
#        [[586, 541]],
#
#        [[586, 542]],
#
#        [[586, 543]],
#
#        [[585, 544]],
#
#        [[585, 545]],
#
#        [[585, 546]],
#
#        [[585, 547]],
#
#        [[585, 548]],
#
#        [[585, 549]],
#
#        [[585, 550]],
#
#        [[585, 551]],
#
#        [[585, 552]],
#
#        [[585, 553]],
#
#        [[585, 554]],
#
#        [[584, 555]],
#
#        [[584, 556]],
#
#        [[584, 557]],
#
#        [[585, 558]],
#
#        [[585, 559]],
#
#        [[585, 560]],
#
#        [[585, 561]],
#
#        [[585, 562]],
#
#        [[585, 563]],
#
#        [[585, 564]],
#
#        [[585, 565]],
#
#        [[585, 566]],
#
#        [[585, 567]],
#
#        [[585, 568]],
#
#        [[585, 569]],
#
#        [[586, 570]],
#
#        [[586, 571]],
#
#        [[586, 572]],
#
#        [[586, 573]],
#
#        [[586, 574]],
#
#        [[587, 575]],
#
#        [[587, 576]],
#
#        [[587, 577]],
#
#        [[587, 578]],
#
#        [[588, 579]],
#
#        [[588, 580]],
#
#        [[588, 581]],
#
#        [[588, 582]],
#
#        [[589, 583]],
#
#        [[589, 584]],
#
#        [[589, 585]],
#
#        [[590, 586]],
#
#        [[590, 587]],
#
#        [[591, 588]],
#
#        [[591, 589]],
#
#        [[591, 590]],
#
#        [[592, 591]],
#
#        [[592, 592]],
#
#        [[592, 593]],
#
#        [[593, 594]],
#
#        [[593, 595]],
#
#        [[594, 596]],
#
#        [[594, 597]],
#
#        [[595, 598]],
#
#        [[595, 599]],
#
#        [[596, 600]],
#
#        [[597, 601]],
#
#        [[597, 602]],
#
#        [[598, 603]],
#
#        [[598, 604]],
#
#        [[599, 605]],
#
#        [[600, 606]],
#
#        [[600, 607]],
#
#        [[601, 608]],
#
#        [[602, 609]],
#
#        [[602, 610]],
#
#        [[603, 611]],
#
#        [[604, 612]],
#
#        [[605, 613]],
#
#        [[605, 614]],
#
#        [[606, 615]],
#
#        [[607, 616]],
#
#        [[608, 617]],
#
#        [[609, 618]],
#
#        [[610, 619]],
#
#        [[611, 620]],
#
#        [[612, 621]],
#
#        [[613, 622]],
#
#        [[614, 623]],
#
#        [[615, 624]],
#
#        [[616, 625]],
#
#        [[617, 626]],
#
#        [[618, 627]],
#
#        [[619, 627]],
#
#        [[620, 628]],
#
#        [[621, 629]],
#
#        [[622, 630]],
#
#        [[623, 630]],
#
#        [[624, 631]],
#
#        [[625, 632]],
#
#        [[626, 633]],
#
#        [[627, 633]],
#
#        [[628, 634]],
#
#        [[629, 634]],
#
#        [[630, 635]],
#
#        [[631, 636]],
#
#        [[632, 636]],
#
#        [[633, 637]],
#
#        [[634, 637]],
#
#        [[635, 638]],
#
#        [[636, 638]],
#
#        [[637, 639]],
#
#        [[638, 639]],
#
#        [[639, 640]],
#
#        [[640, 640]],
#
#        [[641, 641]],
#
#        [[642, 641]],
#
#        [[643, 641]],
#
#        [[644, 642]],
#
#        [[645, 642]],
#
#        [[646, 643]],
#
#        [[647, 643]],
#
#        [[648, 643]],
#
#        [[649, 644]],
#
#        [[650, 644]],
#
#        [[651, 644]],
#
#        [[652, 645]],
#
#        [[653, 645]],
#
#        [[654, 645]],
#
#        [[655, 645]],
#
#        [[656, 646]],
#
#        [[657, 646]],
#
#        [[658, 646]],
#
#        [[659, 646]],
#
#        [[660, 647]],
#
#        [[661, 647]],
#
#        [[662, 647]],
#
#        [[663, 647]],
#
#        [[664, 647]],
#
#        [[665, 647]],
#
#        [[666, 647]],
#
#        [[667, 648]],
#
#        [[668, 648]],
#
#        [[669, 648]],
#
#        [[670, 648]],
#
#        [[671, 648]],
#
#        [[672, 648]],
#
#        [[673, 648]],
#
#        [[674, 648]],
#
#        [[675, 648]],
#
#        [[676, 648]],
#
#        [[677, 648]],
#
#        [[678, 648]],
#
#        [[679, 648]],
#
#        [[680, 648]],
#
#        [[681, 648]],
#
#        [[682, 648]],
#
#        [[683, 648]],
#
#        [[684, 648]],
#
#        [[685, 648]],
#
#        [[686, 648]],
#
#        [[687, 647]],
#
#        [[688, 647]],
#
#        [[689, 647]],
#
#        [[690, 647]],
#
#        [[691, 647]],
#
#        [[692, 647]],
#
#        [[693, 647]],
#
#        [[694, 646]],
#
#        [[695, 646]],
#
#        [[696, 646]],
#
#        [[697, 646]],
#
#        [[698, 646]],
#
#        [[699, 645]],
#
#        [[700, 645]],
#
#        [[701, 645]],
#
#        [[702, 645]],
#
#        [[703, 644]],
#
#        [[704, 644]],
#
#        [[705, 644]],
#
#        [[706, 643]],
#
#        [[707, 643]],
#
#        [[708, 643]],
#
#        [[709, 642]],
#
#        [[710, 642]],
#
#        [[711, 641]],
#
#        [[712, 641]],
#
#        [[713, 641]],
#
#        [[714, 640]],
#
#        [[715, 640]],
#
#        [[716, 639]],
#
#        [[717, 639]],
#
#        [[718, 638]],
#
#        [[719, 638]],
#
#        [[720, 637]],
#
#        [[721, 637]],
#
#        [[722, 636]],
#
#        [[723, 636]],
#
#        [[724, 635]],
#
#        [[725, 634]],
#
#        [[726, 633]],
#
#        [[727, 633]],
#
#        [[728, 632]],
#
#        [[729, 631]],
#
#        [[730, 630]],
#
#        [[731, 630]],
#
#        [[732, 629]],
#
#        [[733, 628]],
#
#        [[734, 627]],
#
#        [[735, 626]],
#
#        [[736, 625]],
#
#        [[737, 624]],
#
#        [[738, 623]],
#
#        [[739, 622]],
#
#        [[740, 621]],
#
#        [[740, 620]],
#
#        [[741, 619]],
#
#        [[742, 618]],
#
#        [[743, 617]],
#
#        [[743, 616]],
#
#        [[744, 615]],
#
#        [[745, 614]],
#
#        [[745, 613]],
#
#        [[746, 612]],
#
#        [[747, 611]],
#
#        [[747, 610]],
#
#        [[748, 609]],
#
#        [[748, 608]],
#
#        [[749, 607]],
#
#        [[749, 606]],
#
#        [[750, 605]],
#
#        [[750, 604]],
#
#        [[751, 603]],
#
#        [[751, 602]],
#
#        [[751, 601]],
#
#        [[752, 600]],
#
#        [[752, 599]],
#
#        [[752, 598]],
#
#        [[753, 597]],
#
#        [[753, 596]],
#
#        [[753, 595]],
#
#        [[754, 594]],
#
#        [[754, 593]],
#
#        [[754, 592]],
#
#        [[754, 591]],
#
#        [[755, 590]],
#
#        [[755, 589]],
#
#        [[755, 588]],
#
#        [[755, 587]],
#
#        [[756, 586]],
#
#        [[756, 585]],
#
#        [[756, 584]],
#
#        [[756, 583]],
#
#        [[756, 582]],
#
#        [[756, 581]],
#
#        [[757, 580]],
#
#        [[757, 579]],
#
#        [[757, 578]],
#
#        [[757, 577]],
#
#        [[757, 576]],
#
#        [[757, 575]],
#
#        [[757, 574]],
#
#        [[757, 573]],
#
#        [[757, 572]],
#
#        [[757, 571]],
#
#        [[757, 570]],
#
#        [[757, 569]],
#
#        [[757, 568]],
#
#        [[757, 567]],
#
#        [[757, 566]],
#
#        [[757, 565]],
#
#        [[757, 564]],
#
#        [[757, 563]],
#
#        [[757, 562]],
#
#        [[757, 561]],
#
#        [[757, 560]],
#
#        [[757, 559]],
#
#        [[756, 558]],
#
#        [[756, 557]],
#
#        [[756, 556]],
#
#        [[756, 555]],
#
#        [[756, 554]],
#
#        [[755, 553]],
#
#        [[755, 552]],
#
#        [[755, 551]],
#
#        [[755, 550]],
#
#        [[755, 549]],
#
#        [[754, 548]],
#
#        [[754, 547]],
#
#        [[754, 546]],
#
#        [[753, 545]],
#
#        [[753, 544]],
#
#        [[753, 543]],
#
#        [[753, 542]],
#
#        [[752, 541]],
#
#        [[752, 540]],
#
#        [[751, 539]],
#
#        [[751, 538]],
#
#        [[751, 537]],
#
#        [[750, 536]],
#
#        [[750, 535]],
#
#        [[750, 534]],
#
#        [[749, 533]],
#
#        [[749, 532]],
#
#        [[748, 531]],
#
#        [[748, 530]],
#
#        [[747, 529]],
#
#        [[747, 528]],
#
#        [[746, 527]],
#
#        [[745, 526]],
#
#        [[745, 525]],
#
#        [[744, 524]],
#
#        [[743, 523]],
#
#        [[743, 522]],
#
#        [[742, 521]],
#
#        [[741, 520]],
#
#        [[741, 519]],
#
#        [[740, 518]],
#
#        [[739, 517]],
#
#        [[739, 516]],
#
#        [[738, 515]],
#
#        [[737, 514]],
#
#        [[737, 513]],
#
#        [[736, 512]],
#
#        [[735, 511]],
#
#        [[734, 510]],
#
#        [[733, 509]],
#
#        [[733, 508]],
#
#        [[732, 507]],
#
#        [[731, 506]],
#
#        [[730, 505]],
#
#        [[729, 504]],
#
#        [[728, 503]],
#
#        [[727, 502]],
#
#        [[726, 501]],
#
#        [[725, 501]],
#
#        [[724, 500]],
#
#        [[723, 499]],
#
#        [[722, 498]],
#
#        [[721, 497]],
#
#        [[720, 496]],
#
#        [[719, 496]],
#
#        [[718, 495]],
#
#        [[717, 494]],
#
#        [[716, 494]],
#
#        [[715, 493]],
#
#        [[714, 492]],
#
#        [[713, 492]],
#
#        [[712, 491]],
#
#        [[711, 490]],
#
#        [[710, 490]],
#
#        [[709, 489]],
#
#        [[708, 489]],
#
#        [[707, 488]],
#
#        [[706, 488]],
#
#        [[705, 487]],
#
#        [[704, 487]],
#
#        [[703, 486]],
#
#        [[702, 486]],
#
#        [[701, 485]],
#
#        [[700, 485]],
#
#        [[699, 484]],
#
#        [[698, 484]],
#
#        [[697, 484]],
#
#        [[696, 483]],
#
#        [[695, 483]],
#
#        [[694, 483]],
#
#        [[693, 482]],
#
#        [[692, 482]],
#
#        [[691, 482]],
#
#        [[690, 481]],
#
#        [[689, 481]],
#
#        [[688, 481]],
#
#        [[687, 480]],
#
#        [[686, 480]],
#
#        [[685, 480]],
#
#        [[684, 480]],
#
#        [[683, 479]],
#
#        [[682, 479]],
#
#        [[681, 479]],
#
#        [[680, 479]],
#
#        [[679, 479]],
#
#        [[678, 478]],
#
#        [[677, 478]],
#
#        [[676, 478]],
#
#        [[675, 478]],
#
#        [[674, 478]],
#
#        [[673, 478]],
#
#        [[672, 478]],
#
#        [[671, 477]],
#
#        [[670, 477]],
#
#        [[669, 477]],
#
#        [[668, 477]],
#
#        [[667, 477]],
#
#        [[666, 477]],
#
#        [[665, 477]],
#
#        [[664, 477]],
#
#        [[663, 477]],
#
#        [[662, 477]],
#
#        [[661, 477]],
#
#        [[660, 477]],
#
#        [[659, 477]],
#
#        [[658, 477]]], dtype=int32), array([[[596, 471]],
#
#        [[595, 472]],
#
#        [[594, 472]],
#
#        [[595, 472]],
#
#        [[596, 471]],
#
#        [[597, 471]]], dtype=int32), array([[[249, 462]],
#
#        [[250, 463]],
#
#        [[250, 464]],
#
#        [[251, 465]],
#
#        [[252, 466]],
#
#        [[252, 465]],
#
#        [[251, 464]],
#
#        [[250, 463]]], dtype=int32), array([[[304, 461]],
#
#        [[303, 462]],
#
#        [[302, 463]],
#
#        [[301, 464]],
#
#        [[300, 465]],
#
#        [[299, 466]],
#
#        [[300, 465]],
#
#        [[301, 465]],
#
#        [[302, 464]],
#
#        [[303, 463]],
#
#        [[304, 462]],
#
#        [[305, 461]]], dtype=int32), array([[[259, 461]],
#
#        [[260, 462]],
#
#        [[260, 463]],
#
#        [[261, 464]],
#
#        [[262, 465]],
#
#        [[262, 464]],
#
#        [[261, 463]],
#
#        [[260, 462]]], dtype=int32), array([[[238, 461]],
#
#        [[238, 462]],
#
#        [[239, 463]],
#
#        [[240, 464]],
#
#        [[241, 465]],
#
#        [[241, 466]],
#
#        [[242, 466]],
#
#        [[241, 465]],
#
#        [[240, 464]],
#
#        [[240, 463]],
#
#        [[239, 462]]], dtype=int32), array([[[193, 461]],
#
#        [[194, 462]],
#
#        [[195, 463]],
#
#        [[196, 463]],
#
#        [[197, 464]],
#
#        [[198, 465]],
#
#        [[199, 465]],
#
#        [[200, 466]],
#
#        [[201, 466]],
#
#        [[202, 467]],
#
#        [[203, 467]],
#
#        [[202, 466]],
#
#        [[201, 466]],
#
#        [[200, 465]],
#
#        [[199, 465]],
#
#        [[198, 464]],
#
#        [[197, 463]],
#
#        [[196, 463]],
#
#        [[195, 462]],
#
#        [[194, 461]]], dtype=int32), array([[[269, 460]],
#
#        [[269, 461]],
#
#        [[270, 462]],
#
#        [[271, 463]],
#
#        [[271, 462]],
#
#        [[270, 461]]], dtype=int32), array([[[262, 460]],
#
#        [[263, 461]],
#
#        [[264, 462]],
#
#        [[263, 461]]], dtype=int32), array([[[251, 460]],
#
#        [[252, 461]],
#
#        [[253, 462]],
#
#        [[254, 463]],
#
#        [[255, 464]],
#
#        [[254, 463]],
#
#        [[253, 462]],
#
#        [[252, 461]],
#
#        [[252, 460]]], dtype=int32), array([[[240, 459]],
#
#        [[241, 460]],
#
#        [[242, 461]],
#
#        [[242, 462]],
#
#        [[243, 463]],
#
#        [[244, 464]],
#
#        [[244, 463]],
#
#        [[243, 462]],
#
#        [[242, 461]],
#
#        [[241, 460]]], dtype=int32), array([[[225, 459]],
#
#        [[226, 460]],
#
#        [[227, 461]],
#
#        [[227, 462]],
#
#        [[228, 463]],
#
#        [[229, 464]],
#
#        [[230, 465]],
#
#        [[229, 464]],
#
#        [[229, 463]],
#
#        [[228, 462]],
#
#        [[227, 461]],
#
#        [[226, 460]],
#
#        [[226, 459]]], dtype=int32), array([[[271, 458]],
#
#        [[272, 459]],
#
#        [[273, 460]],
#
#        [[274, 461]],
#
#        [[273, 460]],
#
#        [[272, 459]]], dtype=int32), array([[[228, 457]],
#
#        [[229, 458]],
#
#        [[229, 459]],
#
#        [[230, 460]],
#
#        [[231, 461]],
#
#        [[232, 462]],
#
#        [[232, 463]],
#
#        [[233, 463]],
#
#        [[232, 462]],
#
#        [[231, 461]],
#
#        [[231, 460]],
#
#        [[230, 459]],
#
#        [[229, 458]]], dtype=int32), array([[[211, 453]],
#
#        [[211, 454]],
#
#        [[212, 455]],
#
#        [[213, 456]],
#
#        [[213, 457]],
#
#        [[214, 458]],
#
#        [[215, 459]],
#
#        [[216, 460]],
#
#        [[217, 461]],
#
#        [[216, 460]],
#
#        [[215, 459]],
#
#        [[215, 458]],
#
#        [[214, 457]],
#
#        [[213, 456]],
#
#        [[212, 455]],
#
#        [[212, 454]]], dtype=int32), array([[[206, 453]],
#
#        [[206, 454]]], dtype=int32), array([[[414, 452]],
#
#        [[413, 453]],
#
#        [[412, 453]],
#
#        ...,
#
#        [[417, 452]],
#
#        [[416, 452]],
#
#        [[415, 452]]], dtype=int32), array([[[213, 451]],
#
#        [[214, 452]],
#
#        [[214, 453]],
#
#        [[215, 454]],
#
#        [[216, 455]],
#
#        [[217, 456]],
#
#        [[217, 457]],
#
#        [[218, 458]],
#
#        [[219, 459]],
#
#        [[220, 460]],
#
#        [[219, 459]],
#
#        [[219, 458]],
#
#        [[218, 457]],
#
#        [[217, 456]],
#
#        [[216, 455]],
#
#        [[216, 454]],
#
#        [[215, 453]],
#
#        [[214, 452]]], dtype=int32), array([[[324, 444]],
#
#        [[323, 445]],
#
#        [[322, 446]],
#
#        [[322, 447]],
#
#        [[321, 448]],
#
#        [[320, 449]],
#
#        [[319, 450]],
#
#        [[318, 451]],
#
#        [[317, 452]],
#
#        [[316, 452]],
#
#        [[315, 453]],
#
#        [[314, 454]],
#
#        [[315, 454]],
#
#        [[316, 453]],
#
#        [[317, 452]],
#
#        [[318, 452]],
#
#        [[319, 451]],
#
#        [[320, 450]],
#
#        [[321, 449]],
#
#        [[322, 448]],
#
#        [[322, 447]],
#
#        [[323, 446]],
#
#        [[323, 445]]], dtype=int32), array([[[321, 443]],
#
#        [[320, 444]],
#
#        [[319, 445]],
#
#        [[318, 446]],
#
#        [[317, 447]],
#
#        [[316, 448]],
#
#        [[315, 449]],
#
#        [[314, 450]],
#
#        [[313, 451]],
#
#        [[314, 450]],
#
#        [[315, 450]],
#
#        [[316, 449]],
#
#        [[317, 448]],
#
#        [[318, 447]],
#
#        [[319, 446]],
#
#        [[320, 445]],
#
#        [[321, 444]]], dtype=int32), array([[[212, 441]],
#
#        [[213, 442]],
#
#        [[213, 443]],
#
#        [[214, 444]],
#
#        [[215, 445]],
#
#        [[215, 446]],
#
#        [[216, 447]],
#
#        [[217, 448]],
#
#        [[217, 447]],
#
#        [[216, 446]],
#
#        [[215, 445]],
#
#        [[214, 444]],
#
#        [[214, 443]],
#
#        [[213, 442]]], dtype=int32), array([[[214, 438]],
#
#        [[214, 439]],
#
#        [[215, 440]],
#
#        [[216, 441]],
#
#        [[216, 442]],
#
#        [[217, 443]],
#
#        [[218, 444]],
#
#        [[219, 445]],
#
#        [[220, 446]],
#
#        [[219, 445]],
#
#        [[219, 444]],
#
#        [[218, 443]],
#
#        [[217, 442]],
#
#        [[216, 441]],
#
#        [[215, 440]],
#
#        [[215, 439]]], dtype=int32), array([[[218, 435]],
#
#        [[218, 436]],
#
#        [[219, 437]],
#
#        [[220, 438]],
#
#        [[221, 439]],
#
#        [[221, 440]],
#
#        [[222, 441]],
#
#        [[223, 442]],
#
#        [[224, 443]],
#
#        [[225, 444]],
#
#        [[225, 445]],
#
#        [[226, 446]],
#
#        [[227, 447]],
#
#        [[228, 448]],
#
#        [[229, 449]],
#
#        [[228, 448]],
#
#        [[227, 447]],
#
#        [[227, 446]],
#
#        [[226, 445]],
#
#        [[225, 444]],
#
#        [[224, 443]],
#
#        [[224, 442]],
#
#        [[223, 441]],
#
#        [[222, 440]],
#
#        [[221, 439]],
#
#        [[220, 438]],
#
#        [[220, 437]],
#
#        [[219, 436]]], dtype=int32), array([[[220, 433]],
#
#        [[221, 434]],
#
#        [[222, 435]],
#
#        [[223, 436]],
#
#        [[223, 437]],
#
#        [[224, 438]],
#
#        [[225, 439]],
#
#        [[226, 440]],
#
#        [[226, 441]],
#
#        [[227, 442]],
#
#        [[228, 443]],
#
#        [[229, 444]],
#
#        [[229, 445]],
#
#        [[230, 446]],
#
#        [[231, 447]],
#
#        [[231, 446]],
#
#        [[230, 445]],
#
#        [[229, 444]],
#
#        [[228, 443]],
#
#        [[228, 442]],
#
#        [[227, 441]],
#
#        [[226, 440]],
#
#        [[225, 439]],
#
#        [[225, 438]],
#
#        [[224, 437]],
#
#        [[223, 436]],
#
#        [[222, 435]],
#
#        [[222, 434]],
#
#        [[221, 433]]], dtype=int32), array([[[225, 430]],
#
#        [[225, 431]],
#
#        [[226, 432]],
#
#        [[227, 433]],
#
#        [[227, 434]],
#
#        [[228, 435]],
#
#        [[229, 436]],
#
#        [[230, 437]],
#
#        [[230, 438]],
#
#        [[231, 439]],
#
#        [[232, 440]],
#
#        [[233, 441]],
#
#        [[233, 442]],
#
#        [[234, 443]],
#
#        [[235, 444]],
#
#        [[236, 445]],
#
#        [[236, 446]],
#
#        [[237, 447]],
#
#        [[238, 448]],
#
#        [[239, 449]],
#
#        [[240, 450]],
#
#        [[239, 449]],
#
#        [[239, 448]],
#
#        [[238, 447]],
#
#        [[237, 446]],
#
#        [[236, 445]],
#
#        [[235, 444]],
#
#        [[235, 443]],
#
#        [[234, 442]],
#
#        [[233, 441]],
#
#        [[232, 440]],
#
#        [[232, 439]],
#
#        [[231, 438]],
#
#        [[230, 437]],
#
#        [[229, 436]],
#
#        [[229, 435]],
#
#        [[228, 434]],
#
#        [[227, 433]],
#
#        [[226, 432]],
#
#        [[226, 431]]], dtype=int32), array([[[227, 428]],
#
#        [[228, 429]],
#
#        [[228, 430]],
#
#        [[229, 431]],
#
#        [[230, 432]],
#
#        [[231, 433]],
#
#        [[231, 434]],
#
#        [[232, 435]],
#
#        [[233, 436]],
#
#        [[234, 437]],
#
#        [[235, 438]],
#
#        [[235, 439]],
#
#        [[236, 440]],
#
#        [[237, 441]],
#
#        [[238, 442]],
#
#        [[238, 443]],
#
#        [[239, 444]],
#
#        [[240, 445]],
#
#        [[241, 446]],
#
#        [[241, 447]],
#
#        [[242, 448]],
#
#        [[242, 447]],
#
#        [[241, 446]],
#
#        [[240, 445]],
#
#        [[239, 444]],
#
#        [[239, 443]],
#
#        [[238, 442]],
#
#        [[237, 441]],
#
#        [[236, 440]],
#
#        [[236, 439]],
#
#        [[235, 438]],
#
#        [[234, 437]],
#
#        [[233, 436]],
#
#        [[233, 435]],
#
#        [[232, 434]],
#
#        [[231, 433]],
#
#        [[230, 432]],
#
#        [[230, 431]],
#
#        [[229, 430]],
#
#        [[228, 429]]], dtype=int32), array([[[470, 427]],
#
#        [[471, 428]],
#
#        [[471, 429]],
#
#        [[472, 430]],
#
#        [[473, 431]],
#
#        [[474, 432]],
#
#        [[475, 433]],
#
#        [[476, 434]],
#
#        [[477, 435]],
#
#        [[478, 436]],
#
#        [[479, 437]],
#
#        [[480, 438]],
#
#        [[481, 439]],
#
#        [[482, 440]],
#
#        [[483, 441]],
#
#        [[483, 440]],
#
#        [[482, 439]],
#
#        [[481, 438]],
#
#        [[480, 437]],
#
#        [[479, 437]],
#
#        [[478, 436]],
#
#        [[477, 435]],
#
#        [[477, 434]],
#
#        [[476, 433]],
#
#        [[475, 432]],
#
#        [[474, 431]],
#
#        [[473, 430]],
#
#        [[472, 429]],
#
#        [[471, 428]]], dtype=int32), array([[[281, 427]]], dtype=int32), array([[[337, 426]],
#
#        [[337, 427]],
#
#        [[336, 428]],
#
#        [[336, 429]],
#
#        [[335, 430]],
#
#        [[334, 431]],
#
#        [[333, 432]],
#
#        [[332, 433]],
#
#        [[332, 434]],
#
#        [[331, 435]],
#
#        [[332, 434]],
#
#        [[333, 433]],
#
#        [[334, 432]],
#
#        [[335, 431]],
#
#        [[336, 430]],
#
#        [[336, 429]],
#
#        [[336, 428]],
#
#        [[337, 427]]], dtype=int32), array([[[242, 426]],
#
#        [[243, 427]],
#
#        [[244, 428]],
#
#        [[244, 429]],
#
#        [[245, 430]],
#
#        [[246, 431]],
#
#        [[247, 432]],
#
#        [[247, 433]],
#
#        [[248, 434]],
#
#        [[249, 435]],
#
#        [[250, 436]],
#
#        [[251, 437]],
#
#        [[251, 438]],
#
#        [[252, 439]],
#
#        [[253, 440]],
#
#        [[254, 441]],
#
#        [[255, 442]],
#
#        [[255, 443]],
#
#        [[256, 444]],
#
#        [[257, 445]],
#
#        [[258, 446]],
#
#        [[258, 447]],
#
#        [[259, 448]],
#
#        [[260, 448]],
#
#        [[259, 447]],
#
#        [[258, 446]],
#
#        [[257, 445]],
#
#        [[256, 444]],
#
#        [[256, 443]],
#
#        [[255, 442]],
#
#        [[254, 441]],
#
#        [[253, 440]],
#
#        [[253, 439]],
#
#        [[252, 438]],
#
#        [[251, 437]],
#
#        [[250, 436]],
#
#        [[249, 435]],
#
#        [[249, 434]],
#
#        [[248, 433]],
#
#        [[247, 432]],
#
#        [[246, 431]],
#
#        [[246, 430]],
#
#        [[245, 429]],
#
#        [[244, 428]],
#
#        [[243, 427]]], dtype=int32), array([[[232, 426]],
#
#        [[232, 427]],
#
#        [[233, 428]],
#
#        [[234, 429]],
#
#        [[235, 430]],
#
#        [[236, 431]],
#
#        [[236, 432]],
#
#        [[237, 433]],
#
#        [[238, 434]],
#
#        [[239, 435]],
#
#        [[239, 436]],
#
#        [[240, 437]],
#
#        [[241, 438]],
#
#        [[242, 439]],
#
#        [[243, 440]],
#
#        [[243, 441]],
#
#        [[244, 442]],
#
#        [[245, 443]],
#
#        [[246, 444]],
#
#        [[246, 445]],
#
#        [[247, 446]],
#
#        [[248, 447]],
#
#        [[249, 448]],
#
#        [[250, 449]],
#
#        [[249, 448]],
#
#        [[248, 447]],
#
#        [[248, 446]],
#
#        [[247, 445]],
#
#        [[246, 444]],
#
#        [[245, 443]],
#
#        [[245, 442]],
#
#        [[244, 441]],
#
#        [[243, 440]],
#
#        [[242, 439]],
#
#        [[241, 438]],
#
#        [[241, 437]],
#
#        [[240, 436]],
#
#        [[239, 435]],
#
#        [[238, 434]],
#
#        [[238, 433]],
#
#        [[237, 432]],
#
#        [[236, 431]],
#
#        [[235, 430]],
#
#        [[234, 429]],
#
#        [[234, 428]],
#
#        [[233, 427]]], dtype=int32), array([[[335, 424]],
#
#        [[334, 425]],
#
#        [[334, 426]],
#
#        [[333, 427]],
#
#        [[333, 428]],
#
#        [[332, 429]],
#
#        [[331, 430]],
#
#        [[331, 431]],
#
#        [[332, 430]],
#
#        [[333, 429]],
#
#        [[333, 428]],
#
#        [[334, 427]],
#
#        [[334, 426]],
#
#        [[335, 425]]], dtype=int32), array([[[245, 424]],
#
#        [[245, 425]],
#
#        [[246, 426]],
#
#        [[247, 427]],
#
#        [[248, 428]],
#
#        [[249, 429]],
#
#        [[249, 430]],
#
#        [[250, 431]],
#
#        [[251, 432]],
#
#        [[252, 433]],
#
#        [[252, 434]],
#
#        [[253, 435]],
#
#        [[254, 436]],
#
#        [[255, 437]],
#
#        [[256, 438]],
#
#        [[256, 439]],
#
#        [[257, 440]],
#
#        [[258, 441]],
#
#        [[259, 442]],
#
#        [[259, 443]],
#
#        [[260, 444]],
#
#        [[261, 445]],
#
#        [[262, 446]],
#
#        [[261, 445]],
#
#        [[260, 444]],
#
#        [[260, 443]],
#
#        [[259, 442]],
#
#        [[258, 441]],
#
#        [[257, 440]],
#
#        [[257, 439]],
#
#        [[256, 438]],
#
#        [[255, 437]],
#
#        [[254, 436]],
#
#        [[253, 435]],
#
#        [[253, 434]],
#
#        [[252, 433]],
#
#        [[251, 432]],
#
#        [[250, 431]],
#
#        [[250, 430]],
#
#        [[249, 429]],
#
#        [[248, 428]],
#
#        [[247, 427]],
#
#        [[246, 426]],
#
#        [[246, 425]]], dtype=int32), array([[[234, 424]],
#
#        [[235, 425]],
#
#        [[236, 426]],
#
#        [[237, 427]],
#
#        [[237, 428]],
#
#        [[238, 429]],
#
#        [[239, 430]],
#
#        [[240, 431]],
#
#        [[240, 432]],
#
#        [[241, 433]],
#
#        [[242, 434]],
#
#        [[243, 435]],
#
#        [[244, 436]],
#
#        [[244, 437]],
#
#        [[245, 438]],
#
#        [[246, 439]],
#
#        [[247, 440]],
#
#        [[247, 441]],
#
#        [[248, 442]],
#
#        [[249, 443]],
#
#        [[250, 444]],
#
#        [[251, 445]],
#
#        [[251, 446]],
#
#        [[252, 447]],
#
#        [[253, 448]],
#
#        [[252, 447]],
#
#        [[252, 446]],
#
#        [[251, 445]],
#
#        [[250, 444]],
#
#        [[249, 443]],
#
#        [[249, 442]],
#
#        [[248, 441]],
#
#        [[247, 440]],
#
#        [[246, 439]],
#
#        [[245, 438]],
#
#        [[245, 437]],
#
#        [[244, 436]],
#
#        [[243, 435]],
#
#        [[242, 434]],
#
#        [[241, 433]],
#
#        [[241, 432]],
#
#        [[240, 431]],
#
#        [[239, 430]],
#
#        [[238, 429]],
#
#        [[238, 428]],
#
#        [[237, 427]],
#
#        [[236, 426]],
#
#        [[235, 425]]], dtype=int32), array([[[285, 417]],
#
#        [[285, 418]]], dtype=int32), array([[[461, 414]],
#
#        [[462, 415]],
#
#        [[462, 416]],
#
#        [[463, 417]],
#
#        [[463, 418]],
#
#        [[463, 417]],
#
#        [[462, 416]],
#
#        [[462, 415]]], dtype=int32), array([[[318, 398]],
#
#        [[318, 399]]], dtype=int32), array([[[460, 394]],
#
#        [[460, 395]],
#
#        [[461, 396]],
#
#        [[461, 397]],
#
#        [[462, 398]],
#
#        [[462, 399]],
#
#        [[462, 400]],
#
#        [[463, 401]],
#
#        [[463, 402]],
#
#        [[464, 403]],
#
#        [[465, 404]],
#
#        [[465, 405]],
#
#        [[465, 404]],
#
#        [[464, 403]],
#
#        [[464, 402]],
#
#        [[463, 401]],
#
#        [[463, 400]],
#
#        [[462, 399]],
#
#        [[462, 398]],
#
#        [[461, 397]],
#
#        [[461, 396]],
#
#        [[460, 395]]], dtype=int32), array([[[166, 393]],
#
#        [[166, 394]],
#
#        [[167, 395]],
#
#        [[167, 394]]], dtype=int32), array([[[462, 391]],
#
#        [[462, 392]],
#
#        [[462, 393]],
#
#        [[463, 394]],
#
#        [[463, 395]],
#
#        [[464, 396]],
#
#        [[464, 397]],
#
#        [[465, 398]],
#
#        [[465, 399]],
#
#        [[466, 400]],
#
#        [[466, 401]],
#
#        [[467, 402]],
#
#        [[467, 403]],
#
#        [[468, 404]],
#
#        [[468, 405]],
#
#        [[468, 404]],
#
#        [[467, 403]],
#
#        [[467, 402]],
#
#        [[466, 401]],
#
#        [[466, 400]],
#
#        [[466, 399]],
#
#        [[465, 398]],
#
#        [[465, 397]],
#
#        [[464, 396]],
#
#        [[464, 395]],
#
#        [[463, 394]],
#
#        [[463, 393]],
#
#        [[462, 392]]], dtype=int32), array([[[167, 390]],
#
#        [[168, 391]],
#
#        [[169, 392]],
#
#        [[170, 393]],
#
#        [[169, 392]],
#
#        [[168, 391]]], dtype=int32), array([[[178, 382]],
#
#        [[179, 383]],
#
#        [[179, 384]],
#
#        [[180, 385]],
#
#        [[180, 386]],
#
#        [[181, 387]],
#
#        [[182, 388]],
#
#        [[183, 389]],
#
#        [[184, 390]],
#
#        [[183, 389]],
#
#        [[182, 388]],
#
#        [[182, 387]],
#
#        [[181, 386]],
#
#        [[180, 385]],
#
#        [[179, 384]],
#
#        [[179, 383]]], dtype=int32), array([[[180, 380]],
#
#        [[181, 381]],
#
#        [[181, 382]],
#
#        [[182, 383]],
#
#        [[183, 384]],
#
#        [[184, 385]],
#
#        [[184, 386]],
#
#        [[185, 387]],
#
#        [[186, 388]],
#
#        [[187, 389]],
#
#        [[187, 390]],
#
#        [[188, 391]],
#
#        [[189, 392]],
#
#        [[190, 393]],
#
#        [[190, 392]],
#
#        [[189, 391]],
#
#        [[188, 390]],
#
#        [[187, 389]],
#
#        [[187, 388]],
#
#        [[186, 387]],
#
#        [[185, 386]],
#
#        [[184, 385]],
#
#        [[183, 384]],
#
#        [[183, 383]],
#
#        [[182, 382]],
#
#        [[181, 381]]], dtype=int32), array([[[166, 380]],
#
#        [[167, 381]],
#
#        [[167, 382]],
#
#        [[168, 382]],
#
#        [[167, 381]]], dtype=int32), array([[[168, 378]],
#
#        [[169, 379]],
#
#        [[170, 380]],
#
#        [[169, 379]],
#
#        [[169, 378]]], dtype=int32), array([[[316, 377]],
#
#        [[316, 378]],
#
#        [[315, 379]],
#
#        [[315, 380]],
#
#        [[316, 379]],
#
#        [[316, 378]]], dtype=int32), array([[[202, 376]],
#
#        [[202, 377]]], dtype=int32), array([[[314, 375]],
#
#        [[314, 376]],
#
#        [[313, 377]],
#
#        [[313, 378]],
#
#        [[313, 379]],
#
#        [[313, 378]],
#
#        [[313, 377]],
#
#        [[314, 376]]], dtype=int32), array([[[181, 373]],
#
#        [[181, 374]],
#
#        [[182, 375]],
#
#        [[183, 376]],
#
#        [[183, 377]],
#
#        [[184, 378]],
#
#        [[185, 379]],
#
#        [[186, 380]],
#
#        [[186, 381]],
#
#        [[187, 382]],
#
#        [[188, 383]],
#
#        [[189, 384]],
#
#        [[189, 383]],
#
#        [[188, 382]],
#
#        [[187, 381]],
#
#        [[186, 380]],
#
#        [[186, 379]],
#
#        [[185, 378]],
#
#        [[184, 377]],
#
#        [[183, 376]],
#
#        [[183, 375]],
#
#        [[182, 374]]], dtype=int32), array([[[183, 371]],
#
#        [[184, 372]],
#
#        [[184, 373]],
#
#        [[185, 374]],
#
#        [[186, 375]],
#
#        [[187, 376]],
#
#        [[188, 377]],
#
#        [[188, 378]],
#
#        [[189, 379]],
#
#        [[190, 380]],
#
#        [[191, 381]],
#
#        [[191, 382]],
#
#        [[192, 382]],
#
#        [[191, 381]],
#
#        [[190, 380]],
#
#        [[190, 379]],
#
#        [[189, 378]],
#
#        [[188, 377]],
#
#        [[187, 376]],
#
#        [[187, 375]],
#
#        [[186, 374]],
#
#        [[185, 373]],
#
#        [[184, 372]]], dtype=int32), array([[[169, 370]],
#
#        [[169, 371]]], dtype=int32), array([[[201, 369]],
#
#        [[202, 370]],
#
#        [[203, 371]],
#
#        [[203, 370]],
#
#        [[202, 369]]], dtype=int32), array([[[171, 368]]], dtype=int32), array([[[184, 364]],
#
#        [[184, 365]],
#
#        [[185, 366]],
#
#        [[186, 367]],
#
#        [[186, 368]],
#
#        [[187, 369]],
#
#        [[188, 370]],
#
#        [[189, 371]],
#
#        [[190, 371]],
#
#        [[189, 370]],
#
#        [[188, 369]],
#
#        [[187, 368]],
#
#        [[186, 367]],
#
#        [[185, 366]],
#
#        [[185, 365]]], dtype=int32), array([[[187, 363]]], dtype=int32), array([[[169, 362]],
#
#        [[169, 363]]], dtype=int32), array([[[172, 361]],
#
#        [[172, 362]],
#
#        [[173, 363]],
#
#        [[173, 362]]], dtype=int32), array([[[592, 360]],
#
#        [[592, 361]],
#
#        [[593, 362]],
#
#        [[592, 361]]], dtype=int32), array([[[174, 359]],
#
#        [[174, 360]],
#
#        [[175, 360]]], dtype=int32), array([[[168, 358]],
#
#        [[167, 359]],
#
#        [[167, 360]],
#
#        [[167, 361]],
#
#        [[166, 362]],
#
#        [[166, 363]],
#
#        [[166, 362]],
#
#        [[167, 361]],
#
#        [[167, 360]],
#
#        [[167, 359]]], dtype=int32), array([[[175, 353]],
#
#        [[176, 354]]], dtype=int32), array([[[340, 352]],
#
#        [[340, 353]],
#
#        [[340, 354]],
#
#        [[341, 355]],
#
#        [[341, 356]],
#
#        [[341, 357]],
#
#        [[341, 358]],
#
#        [[342, 359]],
#
#        [[342, 360]],
#
#        [[342, 361]],
#
#        [[343, 362]],
#
#        [[343, 363]],
#
#        [[343, 364]],
#
#        [[343, 365]],
#
#        [[343, 366]],
#
#        [[344, 367]],
#
#        [[344, 368]],
#
#        [[344, 369]],
#
#        [[344, 370]],
#
#        [[345, 371]],
#
#        [[345, 372]],
#
#        [[345, 373]],
#
#        [[345, 374]],
#
#        [[345, 375]],
#
#        [[345, 376]],
#
#        [[346, 377]],
#
#        [[346, 378]],
#
#        [[346, 379]],
#
#        [[346, 380]],
#
#        [[346, 381]],
#
#        [[347, 381]],
#
#        [[348, 382]],
#
#        [[349, 383]],
#
#        [[350, 384]],
#
#        [[350, 385]],
#
#        [[350, 386]],
#
#        [[350, 387]],
#
#        [[350, 388]],
#
#        [[350, 389]],
#
#        [[349, 390]],
#
#        [[349, 391]],
#
#        [[349, 392]],
#
#        [[349, 393]],
#
#        [[349, 394]],
#
#        [[348, 395]],
#
#        [[348, 396]],
#
#        [[348, 397]],
#
#        [[348, 398]],
#
#        [[348, 399]],
#
#        [[348, 400]],
#
#        [[347, 401]],
#
#        [[348, 402]],
#
#        [[348, 403]],
#
#        [[347, 404]],
#
#        [[347, 405]],
#
#        [[347, 406]],
#
#        [[347, 407]],
#
#        [[347, 408]],
#
#        [[347, 409]],
#
#        [[347, 410]],
#
#        [[347, 411]],
#
#        [[346, 412]],
#
#        [[346, 413]],
#
#        [[345, 414]],
#
#        [[344, 415]],
#
#        [[344, 416]],
#
#        [[343, 417]],
#
#        [[343, 418]],
#
#        [[342, 419]],
#
#        [[342, 420]],
#
#        [[341, 421]],
#
#        [[341, 422]],
#
#        [[341, 423]],
#
#        [[341, 424]],
#
#        [[340, 425]],
#
#        [[340, 426]],
#
#        [[340, 427]],
#
#        [[339, 428]],
#
#        [[339, 429]],
#
#        [[339, 430]],
#
#        [[338, 431]],
#
#        [[338, 432]],
#
#        [[337, 433]],
#
#        [[336, 434]],
#
#        [[335, 435]],
#
#        [[334, 436]],
#
#        [[334, 437]],
#
#        [[333, 438]],
#
#        [[332, 439]],
#
#        [[331, 440]],
#
#        [[330, 441]],
#
#        [[329, 442]],
#
#        [[328, 443]],
#
#        [[328, 444]],
#
#        [[327, 445]],
#
#        [[327, 446]],
#
#        [[326, 447]],
#
#        [[325, 448]],
#
#        [[324, 449]],
#
#        [[324, 450]],
#
#        [[323, 451]],
#
#        [[322, 452]],
#
#        [[322, 453]],
#
#        [[321, 454]],
#
#        [[320, 454]],
#
#        [[319, 455]],
#
#        [[318, 456]],
#
#        [[317, 456]],
#
#        [[316, 457]],
#
#        [[315, 458]],
#
#        [[314, 458]],
#
#        [[313, 459]],
#
#        [[312, 460]],
#
#        [[311, 460]],
#
#        [[310, 461]],
#
#        [[309, 462]],
#
#        [[308, 463]],
#
#        [[307, 464]],
#
#        [[306, 464]],
#
#        [[305, 465]],
#
#        [[304, 466]],
#
#        [[303, 467]],
#
#        [[302, 468]],
#
#        [[301, 469]],
#
#        [[300, 469]],
#
#        [[299, 470]],
#
#        [[298, 470]],
#
#        [[297, 471]],
#
#        [[296, 471]],
#
#        [[295, 471]],
#
#        [[294, 472]],
#
#        [[293, 472]],
#
#        [[292, 473]],
#
#        [[291, 473]],
#
#        [[290, 473]],
#
#        [[289, 474]],
#
#        [[288, 474]],
#
#        [[287, 474]],
#
#        [[286, 475]],
#
#        [[285, 475]],
#
#        [[284, 476]],
#
#        [[283, 476]],
#
#        [[282, 477]],
#
#        [[281, 477]],
#
#        [[280, 478]],
#
#        [[279, 478]],
#
#        [[278, 479]],
#
#        [[277, 479]],
#
#        [[276, 480]],
#
#        [[275, 480]],
#
#        [[274, 480]],
#
#        [[273, 480]],
#
#        [[272, 480]],
#
#        [[271, 480]],
#
#        [[270, 480]],
#
#        [[269, 480]],
#
#        [[268, 481]],
#
#        [[267, 481]],
#
#        [[266, 481]],
#
#        [[265, 481]],
#
#        [[264, 481]],
#
#        [[263, 481]],
#
#        [[262, 481]],
#
#        [[261, 482]],
#
#        [[260, 482]],
#
#        [[259, 482]],
#
#        [[258, 482]],
#
#        [[257, 482]],
#
#        [[256, 483]],
#
#        [[255, 483]],
#
#        [[254, 483]],
#
#        [[253, 483]],
#
#        [[252, 484]],
#
#        [[251, 484]],
#
#        [[250, 484]],
#
#        [[249, 484]],
#
#        [[248, 483]],
#
#        [[247, 483]],
#
#        [[246, 483]],
#
#        [[245, 483]],
#
#        [[244, 483]],
#
#        [[243, 483]],
#
#        [[242, 482]],
#
#        [[241, 482]],
#
#        [[240, 482]],
#
#        [[239, 482]],
#
#        [[238, 482]],
#
#        [[237, 482]],
#
#        [[236, 482]],
#
#        [[235, 481]],
#
#        [[234, 481]],
#
#        [[233, 481]],
#
#        [[232, 481]],
#
#        [[231, 481]],
#
#        [[230, 481]],
#
#        [[229, 481]],
#
#        [[228, 481]],
#
#        [[227, 481]],
#
#        [[226, 481]],
#
#        [[225, 481]],
#
#        [[224, 481]],
#
#        [[223, 480]],
#
#        [[222, 480]],
#
#        [[221, 479]],
#
#        [[220, 479]],
#
#        [[219, 479]],
#
#        [[218, 478]],
#
#        [[217, 478]],
#
#        [[216, 477]],
#
#        [[215, 477]],
#
#        [[214, 476]],
#
#        [[213, 476]],
#
#        [[212, 476]],
#
# ...
#
#        [[657, 243]],
#
#        [[656, 244]],
#
#        [[655, 244]],
#
#        [[654, 245]],
#
#        [[653, 245]],
#
#        [[652, 246]],
#
#        [[651, 246]],
#
#        [[650, 246]],
#
#        [[649, 247]],
#
#        [[648, 247]],
#
#        [[647, 248]],
#
#        [[646, 248]],
#
#        [[645, 248]],
#
#        [[644, 248]],
#
#        [[643, 249]],
#
#        [[642, 249]],
#
#        [[641, 249]],
#
#        [[640, 249]],
#
#        [[639, 250]],
#
#        [[638, 250]],
#
#        [[637, 250]],
#
#        [[636, 250]],
#
#        [[635, 250]],
#
#        [[634, 251]],
#
#        [[633, 251]],
#
#        [[632, 251]],
#
#        [[631, 251]],
#
#        [[630, 251]],
#
#        [[629, 251]],
#
#        [[628, 251]],
#
#        [[627, 251]],
#
#        [[626, 251]],
#
#        [[625, 251]],
#
#        [[624, 251]],
#
#        [[623, 252]],
#
#        [[622, 252]],
#
#        [[621, 252]],
#
#        [[620, 252]],
#
#        [[619, 252]],
#
#        [[618, 252]],
#
#        [[617, 252]],
#
#        [[616, 252]],
#
#        [[615, 251]],
#
#        [[614, 251]],
#
#        [[613, 251]],
#
#        [[612, 251]],
#
#        [[611, 251]],
#
#        [[610, 251]],
#
#        [[609, 251]],
#
#        [[608, 251]],
#
#        [[607, 251]],
#
#        [[606, 251]],
#
#        [[605, 250]],
#
#        [[604, 250]],
#
#        [[603, 250]],
#
#        [[602, 250]],
#
#        [[601, 250]],
#
#        [[600, 250]],
#
#        [[599, 249]],
#
#        [[598, 249]],
#
#        [[597, 249]],
#
#        [[596, 249]],
#
#        [[595, 248]],
#
#        [[594, 248]],
#
#        [[593, 248]],
#
#        [[592, 247]],
#
#        [[591, 247]],
#
#        [[590, 247]],
#
#        [[589, 247]],
#
#        [[588, 246]],
#
#        [[587, 246]],
#
#        [[586, 245]],
#
#        [[585, 245]],
#
#        [[584, 245]],
#
#        [[583, 244]],
#
#        [[582, 244]],
#
#        [[581, 243]],
#
#        [[580, 243]],
#
#        [[579, 242]],
#
#        [[578, 242]],
#
#        [[577, 241]],
#
#        [[576, 241]],
#
#        [[575, 240]],
#
#        [[574, 240]],
#
#        [[573, 239]],
#
#        [[572, 239]],
#
#        [[571, 238]],
#
#        [[570, 237]],
#
#        [[569, 237]],
#
#        [[568, 236]],
#
#        [[567, 236]],
#
#        [[566, 235]],
#
#        [[565, 234]],
#
#        [[564, 233]],
#
#        [[563, 233]],
#
#        [[562, 232]],
#
#        [[561, 231]],
#
#        [[560, 230]],
#
#        [[559, 230]],
#
#        [[558, 229]],
#
#        [[557, 228]],
#
#        [[556, 227]],
#
#        [[555, 226]],
#
#        [[554, 225]],
#
#        [[553, 224]],
#
#        [[552, 223]],
#
#        [[551, 222]],
#
#        [[550, 221]],
#
#        [[549, 220]],
#
#        [[548, 219]],
#
#        [[548, 218]],
#
#        [[547, 217]],
#
#        [[546, 216]],
#
#        [[545, 215]],
#
#        [[544, 214]],
#
#        [[544, 213]],
#
#        [[543, 212]],
#
#        [[542, 211]],
#
#        [[542, 210]],
#
#        [[541, 209]],
#
#        [[540, 208]],
#
#        [[540, 207]],
#
#        [[539, 206]],
#
#        [[539, 205]],
#
#        [[538, 204]],
#
#        [[538, 203]],
#
#        [[537, 202]],
#
#        [[537, 201]],
#
#        [[536, 200]],
#
#        [[536, 199]],
#
#        [[535, 198]],
#
#        [[535, 197]],
#
#        [[535, 196]],
#
#        [[534, 195]],
#
#        [[534, 194]],
#
#        [[534, 193]],
#
#        [[533, 192]],
#
#        [[533, 191]],
#
#        [[533, 190]],
#
#        [[533, 189]],
#
#        [[532, 188]],
#
#        [[532, 187]],
#
#        [[532, 186]],
#
#        [[532, 185]],
#
#        [[532, 184]],
#
#        [[531, 183]],
#
#        [[531, 182]],
#
#        [[531, 181]],
#
#        [[531, 180]],
#
#        [[531, 179]],
#
#        [[531, 178]],
#
#        [[531, 177]],
#
#        [[531, 176]],
#
#        [[531, 175]],
#
#        [[531, 174]],
#
#        [[531, 173]],
#
#        [[531, 172]],
#
#        [[531, 171]],
#
#        [[531, 170]],
#
#        [[531, 169]],
#
#        [[531, 168]],
#
#        [[531, 167]],
#
#        [[531, 166]],
#
#        [[531, 165]],
#
#        [[532, 164]],
#
#        [[532, 163]],
#
#        [[532, 162]],
#
#        [[532, 161]],
#
#        [[532, 160]],
#
#        [[533, 159]],
#
#        [[533, 158]],
#
#        [[533, 157]],
#
#        [[533, 156]],
#
#        [[533, 155]],
#
#        [[534, 154]],
#
#        [[534, 153]],
#
#        [[534, 152]],
#
#        [[535, 151]],
#
#        [[535, 150]],
#
#        [[535, 149]],
#
#        [[535, 148]],
#
#        [[536, 147]],
#
#        [[536, 146]],
#
#        [[537, 145]],
#
#        [[537, 144]],
#
#        [[538, 143]],
#
#        [[538, 142]],
#
#        [[538, 141]],
#
#        [[539, 140]],
#
#        [[539, 139]],
#
#        [[540, 138]],
#
#        [[541, 137]],
#
#        [[541, 136]],
#
#        [[542, 135]],
#
#        [[542, 134]],
#
#        [[543, 133]],
#
#        [[544, 132]],
#
#        [[544, 131]],
#
#        [[545, 130]],
#
#        [[546, 129]],
#
#        [[547, 128]],
#
#        [[548, 127]],
#
#        [[548, 126]],
#
#        [[549, 125]],
#
#        [[550, 124]],
#
#        [[551, 123]],
#
#        [[552, 122]],
#
#        [[553, 121]],
#
#        [[554, 120]],
#
#        [[555, 120]],
#
#        [[556, 119]],
#
#        [[557, 118]],
#
#        [[558, 117]],
#
#        [[559, 116]],
#
#        [[560, 115]],
#
#        [[561, 115]],
#
#        [[562, 114]],
#
#        [[563, 113]],
#
#        [[564, 113]],
#
#        [[565, 112]],
#
#        [[566, 112]],
#
#        [[567, 111]],
#
#        [[568, 111]],
#
#        [[569, 110]],
#
#        [[570, 109]],
#
#        [[571, 109]],
#
#        [[572, 108]],
#
#        [[573, 108]],
#
#        [[574, 108]],
#
#        [[575, 107]],
#
#        [[576, 106]],
#
#        [[577, 106]],
#
#        [[578, 106]],
#
#        [[579, 105]],
#
#        [[580, 105]],
#
#        [[581, 105]],
#
#        [[582, 104]],
#
#        [[583, 104]],
#
#        [[584, 104]],
#
#        [[585, 103]],
#
#        [[586, 103]],
#
#        [[587, 103]],
#
#        [[588, 103]],
#
#        [[589, 102]],
#
#        [[590, 102]],
#
#        [[591, 102]],
#
#        [[592, 102]],
#
#        [[593, 101]],
#
#        [[594, 101]],
#
#        [[595, 101]],
#
#        [[596, 101]],
#
#        [[597, 101]]], dtype=int32), array([[[599, 100]],
#
#        [[598, 101]],
#
#        [[597, 101]],
#
#        [[596, 101]],
#
#        [[595, 101]],
#
#        [[594, 101]],
#
#        [[593, 101]],
#
#        [[592, 102]],
#
#        [[591, 102]],
#
#        [[590, 102]],
#
#        [[589, 102]],
#
#        [[588, 103]],
#
#        [[587, 103]],
#
#        [[586, 103]],
#
#        [[585, 103]],
#
#        [[584, 104]],
#
#        [[583, 104]],
#
#        [[582, 104]],
#
#        [[581, 105]],
#
#        [[580, 105]],
#
#        [[579, 105]],
#
#        [[578, 106]],
#
#        [[577, 106]],
#
#        [[576, 106]],
#
#        [[575, 107]],
#
#        [[574, 107]],
#
#        [[573, 108]],
#
#        [[572, 108]],
#
#        [[571, 108]],
#
#        [[570, 109]],
#
#        [[569, 109]],
#
#        [[568, 110]],
#
#        [[567, 111]],
#
#        [[566, 111]],
#
#        [[565, 112]],
#
#        [[564, 112]],
#
#        [[563, 113]],
#
#        [[562, 113]],
#
#        [[561, 114]],
#
#        [[560, 115]],
#
#        [[559, 115]],
#
#        [[558, 116]],
#
#        [[557, 117]],
#
#        [[556, 118]],
#
#        [[555, 119]],
#
#        [[554, 120]],
#
#        [[553, 120]],
#
#        [[552, 121]],
#
#        [[551, 122]],
#
#        [[550, 123]],
#
#        [[549, 124]],
#
#        [[548, 125]],
#
#        [[548, 126]],
#
#        [[547, 127]],
#
#        [[546, 128]],
#
#        [[545, 129]],
#
#        [[544, 130]],
#
#        [[544, 131]],
#
#        [[543, 132]],
#
#        [[542, 133]],
#
#        [[542, 134]],
#
#        [[541, 135]],
#
#        [[541, 136]],
#
#        [[540, 137]],
#
#        [[539, 138]],
#
#        [[539, 139]],
#
#        [[538, 140]],
#
#        [[538, 141]],
#
#        [[538, 142]],
#
#        [[537, 143]],
#
#        [[537, 144]],
#
#        [[537, 145]],
#
#        [[536, 146]],
#
#        [[536, 147]],
#
#        [[535, 148]],
#
#        [[535, 149]],
#
#        [[535, 150]],
#
#        [[535, 151]],
#
#        [[534, 152]],
#
#        [[534, 153]],
#
#        [[534, 154]],
#
#        [[533, 155]],
#
#        [[533, 156]],
#
#        [[533, 157]],
#
#        [[533, 158]],
#
#        [[533, 159]],
#
#        [[532, 160]],
#
#        [[532, 161]],
#
#        [[532, 162]],
#
#        [[532, 163]],
#
#        [[532, 164]],
#
#        [[531, 165]],
#
#        [[531, 166]],
#
#        [[531, 167]],
#
#        [[531, 168]],
#
#        [[531, 169]],
#
#        [[531, 170]],
#
#        [[531, 171]],
#
#        [[531, 172]],
#
#        [[531, 173]],
#
#        [[531, 174]],
#
#        [[531, 175]],
#
#        [[531, 176]],
#
#        [[531, 177]],
#
#        [[531, 178]],
#
#        [[531, 179]],
#
#        [[531, 180]],
#
#        [[531, 181]],
#
#        [[531, 182]],
#
#        [[531, 183]],
#
#        [[532, 184]],
#
#        [[532, 185]],
#
#        [[532, 186]],
#
#        [[532, 187]],
#
#        [[532, 188]],
#
#        [[533, 189]],
#
#        [[533, 190]],
#
#        [[533, 191]],
#
#        [[533, 192]],
#
#        [[534, 193]],
#
#        [[534, 194]],
#
#        [[534, 195]],
#
#        [[535, 196]],
#
#        [[535, 197]],
#
#        [[535, 198]],
#
#        [[536, 199]],
#
#        [[536, 200]],
#
#        [[536, 201]],
#
#        [[537, 202]],
#
#        [[537, 203]],
#
#        [[538, 204]],
#
#        [[538, 205]],
#
#        [[539, 206]],
#
#        [[539, 207]],
#
#        [[540, 208]],
#
#        [[540, 209]],
#
#        [[541, 210]],
#
#        [[542, 211]],
#
#        [[542, 212]],
#
#        [[543, 213]],
#
#        [[544, 214]],
#
#        [[544, 215]],
#
#        [[545, 216]],
#
#        [[546, 217]],
#
#        [[547, 218]],
#
#        [[548, 219]],
#
#        [[548, 220]],
#
#        [[549, 221]],
#
#        [[550, 222]],
#
#        [[551, 223]],
#
#        [[552, 224]],
#
#        [[553, 225]],
#
#        [[554, 226]],
#
#        [[555, 227]],
#
#        [[556, 228]],
#
#        [[557, 229]],
#
#        [[558, 230]],
#
#        [[559, 230]],
#
#        [[560, 231]],
#
#        [[561, 232]],
#
#        [[562, 233]],
#
#        [[563, 233]],
#
#        [[564, 234]],
#
#        [[565, 235]],
#
#        [[566, 236]],
#
#        [[567, 236]],
#
#        [[568, 237]],
#
#        [[569, 237]],
#
#        [[570, 238]],
#
#        [[571, 239]],
#
#        [[572, 239]],
#
#        [[573, 240]],
#
#        [[574, 240]],
#
#        [[575, 241]],
#
#        [[576, 241]],
#
#        [[577, 242]],
#
#        [[578, 242]],
#
#        [[579, 243]],
#
#        [[580, 243]],
#
#        [[581, 244]],
#
#        [[582, 244]],
#
#        [[583, 244]],
#
#        [[584, 245]],
#
#        [[585, 245]],
#
#        [[586, 245]],
#
#        [[587, 246]],
#
#        [[588, 246]],
#
#        [[589, 247]],
#
#        [[590, 247]],
#
#        [[591, 247]],
#
#        [[592, 247]],
#
#        [[593, 248]],
#
#        [[594, 248]],
#
#        [[595, 248]],
#
#        [[596, 249]],
#
#        [[597, 249]],
#
#        [[598, 249]],
#
#        [[599, 249]],
#
#        [[600, 250]],
#
#        [[601, 250]],
#
#        [[602, 250]],
#
#        [[603, 250]],
#
#        [[604, 250]],
#
#        [[605, 250]],
#
#        [[606, 251]],
#
#        [[607, 251]],
#
#        [[608, 251]],
#
#        [[609, 251]],
#
#        [[610, 251]],
#
#        [[611, 251]],
#
#        [[612, 251]],
#
#        [[613, 251]],
#
#        [[614, 251]],
#
#        [[615, 251]],
#
#        [[616, 252]],
#
#        [[617, 252]],
#
#        [[618, 252]],
#
#        [[619, 252]],
#
#        [[620, 252]],
#
#        [[621, 252]],
#
#        [[622, 252]],
#
#        [[623, 252]],
#
#        [[624, 251]],
#
#        [[625, 251]],
#
#        [[626, 251]],
#
#        [[627, 251]],
#
#        [[628, 251]],
#
#        [[629, 251]],
#
#        [[630, 251]],
#
#        [[631, 251]],
#
#        [[632, 251]],
#
#        [[633, 251]],
#
#        [[634, 251]],
#
#        [[635, 250]],
#
#        [[636, 250]],
#
#        [[637, 250]],
#
#        [[638, 250]],
#
#        [[639, 250]],
#
#        [[640, 249]],
#
#        [[641, 249]],
#
#        [[642, 249]],
#
#        [[643, 249]],
#
#        [[644, 248]],
#
#        [[645, 248]],
#
#        [[646, 248]],
#
#        [[647, 248]],
#
#        [[648, 247]],
#
#        [[649, 247]],
#
#        [[650, 246]],
#
#        [[651, 246]],
#
#        [[652, 246]],
#
#        [[653, 245]],
#
#        [[654, 245]],
#
#        [[655, 245]],
#
#        [[656, 244]],
#
#        [[657, 244]],
#
#        [[658, 243]],
#
#        [[659, 243]],
#
#        [[660, 242]],
#
#        [[661, 242]],
#
#        [[662, 241]],
#
#        [[663, 241]],
#
#        [[664, 240]],
#
#        [[665, 240]],
#
#        [[666, 239]],
#
#        [[667, 238]],
#
#        [[668, 238]],
#
#        [[669, 237]],
#
#        [[670, 236]],
#
#        [[671, 236]],
#
#        [[672, 235]],
#
#        [[673, 234]],
#
#        [[674, 233]],
#
#        [[675, 232]],
#
#        [[676, 232]],
#
#        [[677, 231]],
#
#        [[678, 230]],
#
#        [[679, 229]],
#
#        [[680, 228]],
#
#        [[681, 227]],
#
#        [[682, 226]],
#
#        [[682, 225]],
#
#        [[683, 224]],
#
#        [[684, 223]],
#
#        [[685, 222]],
#
#        [[686, 221]],
#
#        [[686, 220]],
#
#        [[687, 219]],
#
#        [[688, 218]],
#
#        [[689, 217]],
#
#        [[689, 216]],
#
#        [[690, 215]],
#
#        [[691, 214]],
#
#        [[691, 213]],
#
#        [[692, 212]],
#
#        [[692, 211]],
#
#        [[693, 210]],
#
#        [[693, 209]],
#
#        [[694, 208]],
#
#        [[694, 207]],
#
#        [[695, 206]],
#
#        [[695, 205]],
#
#        [[696, 204]],
#
#        [[696, 203]],
#
#        [[697, 202]],
#
#        [[697, 201]],
#
#        [[697, 200]],
#
#        [[698, 199]],
#
#        [[698, 198]],
#
#        [[698, 197]],
#
#        [[699, 196]],
#
#        [[699, 195]],
#
#        [[699, 194]],
#
#        [[699, 193]],
#
#        [[700, 192]],
#
#        [[700, 191]],
#
#        [[700, 190]],
#
#        [[700, 189]],
#
#        [[700, 188]],
#
#        [[701, 187]],
#
#        [[701, 186]],
#
#        [[701, 185]],
#
#        [[701, 184]],
#
#        [[701, 183]],
#
#        [[701, 182]],
#
#        [[701, 181]],
#
#        [[701, 180]],
#
#        [[701, 179]],
#
#        [[701, 178]],
#
#        [[701, 177]],
#
#        [[701, 176]],
#
#        [[701, 175]],
#
#        [[701, 174]],
#
#        [[701, 173]],
#
#        [[701, 172]],
#
#        [[701, 171]],
#
#        [[700, 170]],
#
#        [[700, 169]],
#
#        [[700, 168]],
#
#        [[700, 167]],
#
#        [[700, 166]],
#
#        [[700, 165]],
#
#        [[700, 164]],
#
#        [[699, 163]],
#
#        [[699, 162]],
#
#        [[699, 161]],
#
#        [[698, 160]],
#
#        [[698, 159]],
#
#        [[698, 158]],
#
#        [[697, 157]],
#
#        [[697, 156]],
#
#        [[697, 155]],
#
#        [[696, 154]],
#
#        [[696, 153]],
#
#        [[695, 152]],
#
#        [[695, 151]],
#
#        [[695, 150]],
#
#        [[694, 149]],
#
#        [[694, 148]],
#
#        [[693, 147]],
#
#        [[693, 146]],
#
#        [[692, 145]],
#
#        [[692, 144]],
#
#        [[691, 143]],
#
#        [[691, 142]],
#
#        [[690, 141]],
#
#        [[689, 140]],
#
#        [[689, 139]],
#
#        [[688, 138]],
#
#        [[687, 137]],
#
#        [[686, 136]],
#
#        [[686, 135]],
#
#        [[685, 134]],
#
#        [[684, 133]],
#
#        [[683, 132]],
#
#        [[682, 131]],
#
#        [[682, 130]],
#
#        [[681, 129]],
#
#        [[680, 128]],
#
#        [[679, 127]],
#
#        [[678, 126]],
#
#        [[677, 125]],
#
#        [[676, 125]],
#
#        [[675, 124]],
#
#        [[674, 123]],
#
#        [[673, 122]],
#
#        [[672, 121]],
#
#        [[671, 120]],
#
#        [[670, 120]],
#
#        [[669, 119]],
#
#        [[668, 118]],
#
#        [[667, 117]],
#
#        [[666, 117]],
#
#        [[665, 116]],
#
#        [[664, 115]],
#
#        [[663, 115]],
#
#        [[662, 114]],
#
#        [[661, 114]],
#
#        [[660, 113]],
#
#        [[659, 112]],
#
#        [[658, 112]],
#
#        [[657, 111]],
#
#        [[656, 111]],
#
#        [[655, 110]],
#
#        [[654, 110]],
#
#        [[653, 109]],
#
#        [[652, 109]],
#
#        [[651, 108]],
#
#        [[650, 108]],
#
#        [[649, 107]],
#
#        [[648, 107]],
#
#        [[647, 107]],
#
#        [[646, 107]],
#
#        [[645, 106]],
#
#        [[644, 106]],
#
#        [[643, 105]],
#
#        [[642, 105]],
#
#        [[641, 105]],
#
#        [[640, 104]],
#
#        [[639, 104]],
#
#        [[638, 104]],
#
#        [[637, 103]],
#
#        [[636, 103]],
#
#        [[635, 103]],
#
#        [[634, 103]],
#
#        [[633, 102]],
#
#        [[632, 102]],
#
#        [[631, 102]],
#
#        [[630, 102]],
#
#        [[629, 102]],
#
#        [[628, 101]],
#
#        [[627, 101]],
#
#        [[626, 101]],
#
#        [[625, 101]],
#
#        [[624, 101]],
#
#        [[623, 101]],
#
#        [[622, 101]],
#
#        [[621, 100]],
#
#        [[620, 100]],
#
#        [[619, 100]],
#
#        [[618, 100]],
#
#        [[617, 100]],
#
#        [[616, 100]],
#
#        [[615, 100]],
#
#        [[614, 100]],
#
#        [[613, 100]],
#
#        [[612, 100]],
#
#        [[611, 100]],
#
#        [[610, 100]],
#
#        [[609, 100]],
#
#        [[608, 100]],
#
#        [[607, 100]],
#
#        [[606, 100]],
#
#        [[605, 100]],
#
#        [[604, 100]],
#
#        [[603, 100]],
#
#        [[602, 100]],
#
#        [[601, 100]],
#
#        [[600, 100]]], dtype=int32), array([[[172,  94]],
#
#        [[173,  93]],
#
#        [[174,  93]],
#
#        ...,
#
#        [[169,  94]],
#
#        [[170,  94]],
#
#        [[171,  94]]], dtype=int32), array([[[173,  93]],
#
#        [[172,  94]],
#
#        [[171,  94]],
#
#        ...,
#
#        [[176,  93]],
#
#        [[175,  93]],
#
#        [[174,  93]]], dtype=int32)]
# -1

# %%
# help(cv2.drawContours)

# %% [markdown]
# [Hint](# "You will need to use cv2.findContours and cv2.drawContours")

# %%
# print the number of contours that has been found
len(contours)
# Out:
# 85

# %% [markdown]
# [Hint](# "Simply use the built it python len funtion -> len(coins_contours)")

# %%
# Load your own images and try the same, Note:
# applying gaussian blur and canny is not necessary but can be useful to clean up the image and get rid of noise

# %% [markdown]
# ## Sorting Contours

# %% [markdown]
# ### By area

# %%
def get_contour_areas(contours):
    all_areas = []
    for contour in contours:
        contour_area = cv2.contourArea(contour)
        all_areas.append(contour_area)
    return all_areas

# %%
# We can sort contours with any function, a really useful way of sorting is by area, in many situations we might
# only want to find the biggest or smallest contours, I'm providing the function I use to get all contour areas
# This function is useful to be able to see at a glance all contours areas and get a sense of what is the biggest 
# And which one is the smallest one, however we will not use this to sort them we can just pass cv2.contourArea 
# To the function that is going to be sorting it later
# Call get_contour_areas an pass in the list of contours you got with openCV and then store the results in a var

# %%
# Print the contour areas to screen

# %%
# Now sort the areas by biggest to smallest and print the sorted areas

# %% [markdown]
# [Hint](# "Use the built it python sorted funtion pass in the cv2.contourArea as the key for sorting")

# %%
# Now sort the areas in the opposite way smallest to biggest and print the sorted areas

# %%
# Filter out only the 5 biggest contours and print them

# %% [markdown]
# [Hint](# "Just slice the array!")

# %%
# Now in a clean image draw the contours you just filtered out and display it

# %%
# Repeat the same with your own images, practice sorting contours and think of how it can be useful
# You might need to sort them by something else, just be creative!

# %% [markdown]
# ### By X coordinate (left to right)

# %%
def get_contour_x_center_coordinate(contours):    
    if cv2.contourArea(contours) > 10:
        M = cv2.moments(contours)
        return(int(M['m10']/M['m00']))

# %% [markdown]
# [OpenCV Moments](https://www.learnopencv.com/find-center-of-blob-centroid-using-opencv-cpp-python/)

# %%
# This is an useful function you can use when you need to sort contours left to right
# Sort the contours this time left to right

# %%
# Draw the contours one at a time and display the images on screen

# %% [markdown]
# [Hint](# "You can just extract the one contour at a time from the list and pass it in to drawContours as a new list that contains that only one contour, you can use a for loop to iterate the contours")

# %%
# Can you think of other ways to sort contours?
