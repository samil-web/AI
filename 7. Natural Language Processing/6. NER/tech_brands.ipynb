# %%
import spacy
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.training import Example
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"


# TBD: Load preferred model
nlp = spacy.load("en_core_web_sm")

with open("electronics.txt") as file:
    dataset = file.read()

doc = nlp(dataset)
#print("entities:",[(ent.text,ent.label_) for ent in doc.ents])
print([ent.text for ent in doc.ents])
words = ["huawei","Xiaomi","Android","Samsung","Nokia","iPhone","Motorola","apple"]

train_data = []
with open("electronics.txt") as file:
     dataset = [line.strip() for line in file if line.strip()]

     for sentence in dataset:
         print("######")
         print("sentence: ", sentence)
         print("######")
         sentence = sentence.lower()
         entities = []
         for word in words:
             word = word.lower()
             if word in sentence:
                 start_index = sentence.index(word)
                 end_index = len(word) + start_index
                 print("word: ", word)
                 print("----------------")
                 print("start index:", start_index)
                 print("end index:", end_index)
                 pos = (start_index, end_index, "tech_brand")
                 entities.append(pos)
         element = (sentence.rstrip('\n'), {"entities": entities})

         train_data.append(element)
         print('----------------')
         print("element:", element)

# STEP 2 - UPDATE MODEL
ner = nlp.get_pipe("ner")

for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])
# TBD: load the needed pipeline
ner = nlp.get_pipe("ner")
# TBD: define the annotations
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])
# TBD: train the model

pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]


# TBD: define the number of iterations, the batch size and the drop according to your experience or using an empirical value
# Train model
with nlp.disable_pipes(*unaffected_pipes):
    for iteration in range(10):
        print("Iteration #" + str(iteration))

        # Data shuffle for each iteration
        random.shuffle(train_data)
        losses = {}
        batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            for text, annotations in batch:
                # Create an Example object
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                # Update the model
                nlp.update([example], losses=losses, drop=0)
        print("Losses:", losses)

# STEP 3 - TEST THE UPDATED MODEL
# Save the model
output_dir = Path("model2")
nlp.to_disk(output_dir)
print("Saved correctly!")

# Load updated model
nlp_updated = spacy.load(output_dir)

# TBD: test with a old sentence
doc = nlp_updated("Techniques used in Huawei is great, and even awesome")
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])
# TBD: test with a new sentence and an old brand
doc = nlp_updated("i really recommend samsung over apple phones")
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])
# TBD: test with a new sentence and a new brand
doc = nlp_updated("Just bought a brandnew sony tablet")
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])

# new sentence, no word
doc = nlp_updated("megan wore a tshirt while she was drinking coffee")
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# ['US', 'Huawei', 'Samsung S20', 'Samsung', 'Samsung', 'the past years', 'Samsung', 'Samsung', 'VLC', 'samsung', 'the s7 days', 'Huawei', 'Huawei', 'USA', '614', 'Huawei', 'July', 'AT&T', 'Tmobile', 'USA', 'US', 'Samsung', 'Apple', 'the last ten years', 'three', 'Huawei', 'English', '5 minutes', 'second', 'Huawei', 'Huawei', 'Huawei', 'Xiaomi', 'Redmi', 'third', 'Xiaomi', 'Xiaomi', 'Xiaomi', 'second', 'second', 'days', 'second', 'Xiaomi', 'XIAOMI', 'Xiaomi', 'MediaTek', 'Xiaomi', 'first', 'First', 'Xiaomi', 'second', 'Xiaomi Mi', 'Xiaomi', 'Android', '200%', 'a couple of months', 'Xiaomi mi10', 'Xiaomi', 'Xiaomi', 'Nokia 3310', 'the Motorola Razr']
# ######
# sentence:  I am being forced to purchase a new device as all US networks are apparently no longer supporting Huawei devices in the very near future.
# ######
# word:  huawei
# ----------------
# start index: 98
# end index: 104
# ----------------
# element: ('i am being forced to purchase a new device as all us networks are apparently no longer supporting huawei devices in the very near future.', {'entities': [(98, 104, 'tech_brand')]})
# ######
# sentence:  Samsung S20 is The best Phone that money can buy
# ######
# word:  samsung
# ----------------
# start index: 0
# end index: 7
# ----------------
# element: ('samsung s20 is the best phone that money can buy', {'entities': [(0, 7, 'tech_brand')]})
# ######
# sentence:  I'm a Samsung fan, design and productivity is amazing and perfect, BUT it have a no-go for me: it poses a risk for phone owners.
# ######
# word:  samsung
# ----------------
# start index: 6
# end index: 13
# ----------------
# element: ("i'm a samsung fan, design and productivity is amazing and perfect, but it have a no-go for me: it poses a risk for phone owners.", {'entities': [(6, 13, 'tech_brand')]})
# ######
# sentence:  The hardware is absolutetly stellar, which is no surprise for Samsung in the past years.
# ######
# word:  samsung
# ----------------
# start index: 62
# end index: 69
# ----------------
# element: ('the hardware is absolutetly stellar, which is no surprise for samsung in the past years.', {'entities': [(62, 69, 'tech_brand')]})
# ######
# sentence:  Unfortunately, same goes for app bloatware, which is also no surprise for Samsung.
# ######
# word:  samsung
# ----------------
# start index: 74
# end index: 81
# ----------------
# element: ('unfortunately, same goes for app bloatware, which is also no surprise for samsung.', {'entities': [(74, 81, 'tech_brand')]})
# ######
# sentence:  The phone feels amazing to the touch. Haven't messed with the camera much but from what I have I can say it's not half bad. I bought a micro sdxc card from Samsung to put all my movies and music on and use VLC to watch/listen and it's great.
# ######
# word:  samsung
# ----------------
# start index: 156
# end index: 163
# ----------------
# element: ("the phone feels amazing to the touch. haven't messed with the camera much but from what i have i can say it's not half bad. i bought a micro sdxc card from samsung to put all my movies and music on and use vlc to watch/listen and it's great.", {'entities': [(156, 163, 'tech_brand')]})
# ######
# sentence:  Last time I checked samsung had there high end devices free to unlock there bootloader. At least from the s7 days .
# ######
# word:  samsung
# ----------------
# start index: 20
# end index: 27
# ----------------
# element: ('last time i checked samsung had there high end devices free to unlock there bootloader. at least from the s7 days .', {'entities': [(20, 27, 'tech_brand')]})
# ######
# sentence:  Techniques used in Huawei is great, and even awesome.
# ######
# word:  huawei
# ----------------
# start index: 19
# end index: 25
# ----------------
# element: ('techniques used in huawei is great, and even awesome.', {'entities': [(19, 25, 'tech_brand')]})
# ######
# sentence:  huawei really did an amazing job.
# ######
# word:  huawei
# ----------------
# start index: 0
# end index: 6
# ----------------
# element: ('huawei really did an amazing job.', {'entities': [(0, 6, 'tech_brand')]})
# ######
# sentence:  Huawei phones are excellent. I have used them for ever, unfortunately they are ban by USA. This is the last phone I am purchasing because the next generations will not work in the ðŸ‡ºðŸ‡¸.
# ######
# word:  huawei
# ----------------
# start index: 0
# end index: 6
# ----------------
# element: ('huawei phones are excellent. i have used them for ever, unfortunately they are ban by usa. this is the last phone i am purchasing because the next generations will not work in the ðÿ‡ºðÿ‡¸.', {'entities': [(0, 6, 'tech_brand')]})
# ######
# sentence:  I ordered a new huawei p30 pro for $ 614 and what I received was crazy, the volume buttons werenâ€™t working and the power button hardly works, the battery drains fast and it was a used phone.
# ######
# word:  huawei
# ----------------
# start index: 16
# end index: 22
# ----------------
# element: ('i ordered a new huawei p30 pro for $ 614 and what i received was crazy, the volume buttons werenâ€™t working and the power button hardly works, the battery drains fast and it was a used phone.', {'entities': [(16, 22, 'tech_brand')]})
# ######
# sentence:  I bought the Huawei P30 Pro in July, which to replace my Iphone. I have been using it every day since then. It works great for both AT&T and Tmobile network in the USA. It is a shame to see the political battle and people can not easily buy a great phone, which has nothing to do with national security. Otherwise, the US should ban Samsung, then all other countries should ban Apple etc. So stupid.
# ######
# word:  huawei
# ----------------
# start index: 13
# end index: 19
# word:  samsung
# ----------------
# start index: 333
# end index: 340
# word:  iphone
# ----------------
# start index: 57
# end index: 63
# word:  apple
# ----------------
# start index: 378
# end index: 383
# ----------------
# element: ('i bought the huawei p30 pro in july, which to replace my iphone. i have been using it every day since then. it works great for both at&t and tmobile network in the usa. it is a shame to see the political battle and people can not easily buy a great phone, which has nothing to do with national security. otherwise, the us should ban samsung, then all other countries should ban apple etc. so stupid.', {'entities': [(13, 19, 'tech_brand'), (333, 340, 'tech_brand'), (57, 63, 'tech_brand'), (378, 383, 'tech_brand')]})
# ######
# sentence:  For the money, this phone represents a real bargain. I have been an iphone user for the last ten years, have shown loyalty to the brand and have bought three sim free units during this time. Without question, the Huawei wipes the floor with what I am used to - easily navigated set up and subsequent user menus in real English, superbly constructed, lightening fast loading of websites/data, no irratating and obtrusive update and running out of icloud data prompts ever 5 minutes and an amazing camera.
# ######
# word:  huawei
# ----------------
# start index: 213
# end index: 219
# word:  iphone
# ----------------
# start index: 68
# end index: 74
# ----------------
# element: ('for the money, this phone represents a real bargain. i have been an iphone user for the last ten years, have shown loyalty to the brand and have bought three sim free units during this time. without question, the huawei wipes the floor with what i am used to - easily navigated set up and subsequent user menus in real english, superbly constructed, lightening fast loading of websites/data, no irratating and obtrusive update and running out of icloud data prompts ever 5 minutes and an amazing camera.', {'entities': [(213, 219, 'tech_brand'), (68, 74, 'tech_brand')]})
# ######
# sentence:  Incredible phone. My second from Huawei and hoping they stop this nonsense to block apps in their phones as they are perfect. Good value, beautiful device, fast, easy to use, outstanding camera, etc.
# ######
# word:  huawei
# ----------------
# start index: 33
# end index: 39
# ----------------
# element: ('incredible phone. my second from huawei and hoping they stop this nonsense to block apps in their phones as they are perfect. good value, beautiful device, fast, easy to use, outstanding camera, etc.', {'entities': [(33, 39, 'tech_brand')]})
# ######
# sentence:  Everything is fine with huawei phones I think I've been wasting my time and money with iPhone. Huawei gives you more options and more services with less money so my recommendation is don't buy iPhone. I phone is finished long time ago.
# ######
# word:  huawei
# ----------------
# start index: 24
# end index: 30
# word:  iphone
# ----------------
# start index: 87
# end index: 93
# ----------------
# element: ("everything is fine with huawei phones i think i've been wasting my time and money with iphone. huawei gives you more options and more services with less money so my recommendation is don't buy iphone. i phone is finished long time ago.", {'entities': [(24, 30, 'tech_brand'), (87, 93, 'tech_brand')]})
# ######
# sentence:  For me Huawei are delivering great products at proper prices and are really getting it right. Anybody like me who is worried to leave apple jail, break out it's really good outside!!
# ######
# word:  huawei
# ----------------
# start index: 7
# end index: 13
# word:  apple
# ----------------
# start index: 134
# end index: 139
# ----------------
# element: ("for me huawei are delivering great products at proper prices and are really getting it right. anybody like me who is worried to leave apple jail, break out it's really good outside!!", {'entities': [(7, 13, 'tech_brand'), (134, 139, 'tech_brand')]})
# ######
# sentence:  Thank you for huawei !
# ######
# word:  huawei
# ----------------
# start index: 14
# end index: 20
# ----------------
# element: ('thank you for huawei !', {'entities': [(14, 20, 'tech_brand')]})
# ######
# sentence:  I really love Xiaomi and Redmi phones. This is my third one and I've usually had a good experience with them.
# ######
# word:  xiaomi
# ----------------
# start index: 14
# end index: 20
# ----------------
# element: ("i really love xiaomi and redmi phones. this is my third one and i've usually had a good experience with them.", {'entities': [(14, 20, 'tech_brand')]})
# ######
# sentence:  I've been contemplating on buying a Xiaomi smartphone for quite some time and had tried the Redmi Go on an impulse purchase, saw the Redmi 8 and decided to sit it out, then came the Redmi 9 and so did reviews. I watched a few video reviews and tutorials on how to maximize your experience before purchasing. Here are my thoughts.
# ######
# word:  xiaomi
# ----------------
# start index: 36
# end index: 42
# ----------------
# element: ("i've been contemplating on buying a xiaomi smartphone for quite some time and had tried the redmi go on an impulse purchase, saw the redmi 8 and decided to sit it out, then came the redmi 9 and so did reviews. i watched a few video reviews and tutorials on how to maximize your experience before purchasing. here are my thoughts.", {'entities': [(36, 42, 'tech_brand')]})
# ######
# sentence:  This is where I'm highly mixed with Xiaomi phones.
# ######
# word:  xiaomi
# ----------------
# start index: 36
# end index: 42
# ----------------
# element: ("this is where i'm highly mixed with xiaomi phones.", {'entities': [(36, 42, 'tech_brand')]})
# ######
# sentence:  If you are using Xiaomi smartphones you are dealing with ads and a bunch of bloatware you aren't immediately able to uninstall without special tools.
# ######
# word:  xiaomi
# ----------------
# start index: 17
# end index: 23
# ----------------
# element: ("if you are using xiaomi smartphones you are dealing with ads and a bunch of bloatware you aren't immediately able to uninstall without special tools.", {'entities': [(17, 23, 'tech_brand')]})
# ######
# sentence:  Great cell phone, fast, good photos, battery lasts a long time. Super worth it, it's my second xiaomi and I don't want another brand anymore.
# ######
# word:  xiaomi
# ----------------
# start index: 95
# end index: 101
# ----------------
# element: ("great cell phone, fast, good photos, battery lasts a long time. super worth it, it's my second xiaomi and i don't want another brand anymore.", {'entities': [(95, 101, 'tech_brand')]})
# ######
# sentence:  It's my second Xiaomi and I intend to stay in it for now. Best cost benefit.
# ######
# word:  xiaomi
# ----------------
# start index: 15
# end index: 21
# ----------------
# element: ("it's my second xiaomi and i intend to stay in it for now. best cost benefit.", {'entities': [(15, 21, 'tech_brand')]})
# ######
# sentence:  Battery lasts for days, great camera, second time I buy a Xiaomi phone and I am super satisfied.
# ######
# word:  xiaomi
# ----------------
# start index: 58
# end index: 64
# ----------------
# element: ('battery lasts for days, great camera, second time i buy a xiaomi phone and i am super satisfied.', {'entities': [(58, 64, 'tech_brand')]})
# ######
# sentence:  Very good product, xiaomi and another level, very attentive seller ball show...
# ######
# word:  xiaomi
# ----------------
# start index: 19
# end index: 25
# ----------------
# element: ('very good product, xiaomi and another level, very attentive seller ball show...', {'entities': [(19, 25, 'tech_brand')]})
# ######
# sentence:  Xiaomi great for photos, lots of memory to store everyday photos and documents. I recommend it!!
# ######
# word:  xiaomi
# ----------------
# start index: 0
# end index: 6
# ----------------
# element: ('xiaomi great for photos, lots of memory to store everyday photos and documents. i recommend it!!', {'entities': [(0, 6, 'tech_brand')]})
# ######
# sentence:  Buying original XIAOMI is pure tranquility. Quality product guarantee and good price.
# ######
# word:  xiaomi
# ----------------
# start index: 16
# end index: 22
# ----------------
# element: ('buying original xiaomi is pure tranquility. quality product guarantee and good price.', {'entities': [(16, 22, 'tech_brand')]})
# ######
# sentence:  It arrived in perfect condition, the phone could come more the fault of xiaomi still great device!
# ######
# word:  xiaomi
# ----------------
# start index: 72
# end index: 78
# ----------------
# element: ('it arrived in perfect condition, the phone could come more the fault of xiaomi still great device!', {'entities': [(72, 78, 'tech_brand')]})
# ######
# sentence:  Excellent device Xiaomi does not disappoint quality and performance like few, an excellent cost benefit
# ######
# word:  xiaomi
# ----------------
# start index: 17
# end index: 23
# ----------------
# element: ('excellent device xiaomi does not disappoint quality and performance like few, an excellent cost benefit', {'entities': [(17, 23, 'tech_brand')]})
# ######
# sentence:  Wonderful device as it was expected to be a xiaomi, you can buy without regrets
# ######
# word:  xiaomi
# ----------------
# start index: 44
# end index: 50
# ----------------
# element: ('wonderful device as it was expected to be a xiaomi, you can buy without regrets', {'entities': [(44, 50, 'tech_brand')]})
# ######
# sentence:  battery lasts well, I love xiaomi phones, for me there's no better
# ######
# word:  xiaomi
# ----------------
# start index: 27
# end index: 33
# ----------------
# element: ("battery lasts well, i love xiaomi phones, for me there's no better", {'entities': [(27, 33, 'tech_brand')]})
# ######
# sentence:  Best cost benefit, xiaomi making me lose the prejudice of MediaTek
# ######
# word:  xiaomi
# ----------------
# start index: 19
# end index: 25
# ----------------
# element: ('best cost benefit, xiaomi making me lose the prejudice of mediatek', {'entities': [(19, 25, 'tech_brand')]})
# ######
# sentence:  I liked everything, recommend it! Another quality Xiaomi product...
# ######
# word:  xiaomi
# ----------------
# start index: 50
# end index: 56
# ----------------
# element: ('i liked everything, recommend it! another quality xiaomi product...', {'entities': [(50, 56, 'tech_brand')]})
# ######
# sentence:  I loved it very good, and my first xiaomi. Battery lasts all day excellent.
# ######
# word:  xiaomi
# ----------------
# start index: 35
# end index: 41
# ----------------
# element: ('i loved it very good, and my first xiaomi. battery lasts all day excellent.', {'entities': [(35, 41, 'tech_brand')]})
# ######
# sentence:  Xiaomi speaks for itself! Excellent cost for money!
# ######
# word:  xiaomi
# ----------------
# start index: 0
# end index: 6
# ----------------
# element: ('xiaomi speaks for itself! excellent cost for money!', {'entities': [(0, 6, 'tech_brand')]})
# ######
# sentence:  First time using Xiaomi and well worth it
# ######
# word:  xiaomi
# ----------------
# start index: 17
# end index: 23
# ----------------
# element: ('first time using xiaomi and well worth it', {'entities': [(17, 23, 'tech_brand')]})
# ######
# sentence:  This is my second Xiaomi so far and very pleased
# ######
# word:  xiaomi
# ----------------
# start index: 18
# end index: 24
# ----------------
# element: ('this is my second xiaomi so far and very pleased', {'entities': [(18, 24, 'tech_brand')]})
# ######
# sentence:  I definitely do not like it like my Xiaomi Mi 9t pro, I hate the proximity sensor, it wasn't new but refurbished or it seamed like refurbished, the screen had clearly signs of use. Do not recommend it.
# ######
# word:  xiaomi
# ----------------
# start index: 36
# end index: 42
# ----------------
# element: ("i definitely do not like it like my xiaomi mi 9t pro, i hate the proximity sensor, it wasn't new but refurbished or it seamed like refurbished, the screen had clearly signs of use. do not recommend it.", {'entities': [(36, 42, 'tech_brand')]})
# ######
# sentence:  Great mobile, an iPhone with Xiaomi flag and Android operating system, great cost benefit I'm 200% satisfied.
# ######
# word:  xiaomi
# ----------------
# start index: 29
# end index: 35
# word:  android
# ----------------
# start index: 45
# end index: 52
# word:  iphone
# ----------------
# start index: 17
# end index: 23
# ----------------
# element: ("great mobile, an iphone with xiaomi flag and android operating system, great cost benefit i'm 200% satisfied.", {'entities': [(29, 35, 'tech_brand'), (45, 52, 'tech_brand'), (17, 23, 'tech_brand')]})
# ######
# sentence:  After a couple of months from my purchase I tell you a bit of Xiaomi mi10t.
# ######
# word:  xiaomi
# ----------------
# start index: 62
# end index: 68
# ----------------
# element: ('after a couple of months from my purchase i tell you a bit of xiaomi mi10t.', {'entities': [(62, 68, 'tech_brand')]})
# ######
# sentence:  Xiaomi is loosely with other manufacturers. No useless apps or pre-installed games you want. I'm sure that was not the last phone from Xiaomi. The battery delivers what it promises. Long endurance and fast loading.
# ######
# word:  xiaomi
# ----------------
# start index: 0
# end index: 6
# ----------------
# element: ("xiaomi is loosely with other manufacturers. no useless apps or pre-installed games you want. i'm sure that was not the last phone from xiaomi. the battery delivers what it promises. long endurance and fast loading.", {'entities': [(0, 6, 'tech_brand')]})
# ######
# sentence:  The new Oppo has fully satisfied me.
# ######
# ----------------
# element: ('the new oppo has fully satisfied me.', {'entities': []})
# ######
# sentence:  How I miss my Nokia 3310!
# ######
# word:  nokia
# ----------------
# start index: 14
# end index: 19
# ----------------
# element: ('how i miss my nokia 3310!', {'entities': [(14, 19, 'tech_brand')]})
# ######
# sentence:  If I had to spend some money to buy myself a new phone, I would definitely buy the latest iPhone model.
# ######
# word:  iphone
# ----------------
# start index: 90
# end index: 96
# ----------------
# element: ('if i had to spend some money to buy myself a new phone, i would definitely buy the latest iphone model.', {'entities': [(90, 96, 'tech_brand')]})
# ######
# sentence:  Do you remember the Motorola Razr? It was so small and compact!
# ######
# word:  motorola
# ----------------
# start index: 20
# end index: 28
# ----------------
# element: ('do you remember the motorola razr? it was so small and compact!', {'entities': [(20, 28, 'tech_brand')]})
# Iteration #0
# Losses: {'ner': 86.67213742616488}
# Iteration #1
# Losses: {'ner': 9.361539142612841}
# Iteration #2
# Losses: {'ner': 5.0508312691820425}
# Iteration #3
# Losses: {'ner': 1.8658088178463228}
# Iteration #4
# Losses: {'ner': 1.9164092520878697}
# Iteration #5
# Losses: {'ner': 0.563540561050308}
# Iteration #6
# Losses: {'ner': 0.010793667716485548}
# Iteration #7
# Losses: {'ner': 0.003601243808282415}
# Iteration #8
# Losses: {'ner': 8.484340042629012e-08}
# Iteration #9
# Losses: {'ner': 1.4907464068092586e-07}
# Saved correctly!
# entities: [('Huawei', 'tech_brand')]
# entities: [('samsung', 'tech_brand'), ('apple', 'tech_brand')]
# entities: [('sony', 'tech_brand')]
# entities: []
