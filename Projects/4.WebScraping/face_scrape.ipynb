# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
# from BS4 import BeautifulSoup
URL = 'https://m.facebook.com/story.php?story_fbid=4465924213474547&id=639288689471471'
page = requests.get(URL)

soup = BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html lang="az" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Şəbəkə - 🇮🇷 İran Azərbaycandan nə istəyir? Bizə qarşı niyə... | Facebook
#   </title>
#   <meta content="default" id="meta_referrer" name="referrer"/>
#   <style nonce="peLXXlUF" type="text/css">
# ...

# %%
content  = soup.find_all(class_ = 'co')

# %%
content
# Out:
# [<div class="co"><span>1.İran bizim İsraillə olan münasibətimizdə</span><wbr/><span class="word_break"></span>n narahatdır.<br/> 2.Qarabağın azad olunması ilə başlarına daş düşdü.<br/> 3.Güney Azərbaycan məsələsi.</div>,
#  <div class="co"><span>Burda Tema başqa Temadı hissleri qezebi bir kenara qoyub mentiqli düşünende ortada iqtisadi tema var Irani qîcıqlandıran mesele budur.Çox gümanki zengezur maqistraliyla açılacaq yeni iqtisadi yol Iranı kenara qoyur ve Iranin itkileri olacaq.Irana qıcıq veren bu meseledi.Yoxsak</span><wbr/><span class="word_break"></span>ı heçkim heçkime gülle atan deyil.Tema ne din teması deyil nede  torpaq.Mesele "Money"-di.</div>,
#  <div class="co">İranın nə istədiyinə politoloqlar cavab verər,amma bir şeyə əminəm ki,İran ölkəmizdəki tulalarına arxayın olub belə rahat danışır.</div>,
# ...

# %%
parent = content[1].parent
co = parent.find('span')
print(co.text)
# Out:
# Burda Tema başqa Temadı hissleri qezebi bir kenara qoyub mentiqli düşünende ortada iqtisadi tema var Irani qîcıqlandıran mesele budur.Çox gümanki zengezur maqistraliyla açılacaq yeni iqtisadi yol Iranı kenara qoyur ve Iranin itkileri olacaq.Irana qıcıq veren bu meseledi.Yoxsak

# %%
comments = []

for i in range(len(content)):
    # print(content[i].text)

    # parent = content[i].parent
    # co = parent.find('span')
    comments.append(content[i].text)
# print(co.text)
# 1.İran bizim İsraillə olan münasibətimizdən narahatdır. 2.Qarabağın azad olunması ilə başlarına daş düşdü. 3.Güney Azərbaycan məsələsi.
#

# %%
comments
# Out:
# ['1.İran bizim İsraillə olan münasibətimizdən narahatdır. 2.Qarabağın azad olunması ilə başlarına daş düşdü. 3.Güney Azərbaycan məsələsi.',
#  'Burda Tema başqa Temadı hissleri qezebi bir kenara qoyub mentiqli düşünende ortada iqtisadi tema var Irani qîcıqlandıran mesele budur.Çox gümanki zengezur maqistraliyla açılacaq yeni iqtisadi yol Iranı kenara qoyur ve Iranin itkileri olacaq.Irana qıcıq veren bu meseledi.Yoxsakı heçkim heçkime gülle atan deyil.Tema ne din teması deyil nede  torpaq.Mesele "Money"-di.',
#  'İranın nə istədiyinə politoloqlar cavab verər,amma bir şeyə əminəm ki,İran ölkəmizdəki tulalarına arxayın olub belə rahat danışır.',
#  'İran bizden artiq qorxur.çünki biz güclü dövletik.iran bilir ki,artiq onun serhed qonşusu torpagi işgal altinda olan ezik dövlet deyil ve indi Qarabagi ermeniden alan Azerbaycan 30 il sonrq bir az da dirçelib onlardan Tebrizi,Erdebili,Xorasani teleb edecek.biz artiq onlar üçün potensial tehlükeyik',
# ...

# %%
for i in range(len(content)):
    print(content[i].parent)
# Out:
# <div><h3><a class="cn bu" href="/aysel.khudiyeva?rc=p&amp;refid=52&amp;__tn__=R">Aysel Khudiyeva</a></h3><div class="co"><span>1.İran bizim İsraillə olan münasibətimizdə</span><wbr/><span class="word_break"></span>n narahatdır.<br/> 2.Qarabağın azad olunması ilə başlarına daş düşdü.<br/> 3.Güney Azərbaycan məsələsi.</div><div class="cp"></div><div class="cq cr bc"><span class="cs"><span class="ct cc"><a class="cu cv" href="/4465961353470833/likes/?cancel_uri=https%3A%2F%2Fm.facebook.com%2Fstory.php%3Fstory_fbid%3D4465924213474547%26id%3D639288689471471&amp;refid=52&amp;__tn__=R"><img class="cw p" height="9" src="https://static.xx.fbcdn.net/rsrc.php/v3/yz/r/9LoyWtxbXTT.png" width="10"/>115</a></span></span><span> · </span><abbr>Bazar günü, saat 15:04</abbr></div><div class="cx"><div class="cy" id="comment_replies_more_1:4465924213474547_4465961353470833"><div class="cq cz da"><a href="/comment/replies/?ctoken=4465924213474547_4465961353470833&amp;count=3&amp;curr&amp;pc=1&amp;ft_ent_i
# ...

# %%
print(len(content))
print(content[1])
# Out:
# 40
# <div class="co"><span>Burda Tema başqa Temadı hissleri qezebi bir kenara qoyub mentiqli düşünende ortada iqtisadi tema var Irani qîcıqlandıran mesele budur.Çox gümanki zengezur maqistraliyla açılacaq yeni iqtisadi yol Iranı kenara qoyur ve Iranin itkileri olacaq.Irana qıcıq veren bu meseledi.Yoxsak</span><wbr/><span class="word_break"></span>ı heçkim heçkime gülle atan deyil.Tema ne din teması deyil nede  torpaq.Mesele "Money"-di.</div>

# %%
comments
# Out:
# ['1.İran bizim İsraillə olan münasibətimizdən narahatdır. 2.Qarabağın azad olunması ilə başlarına daş düşdü. 3.Güney Azərbaycan məsələsi.',
#  'Burda Tema başqa Temadı hissleri qezebi bir kenara qoyub mentiqli düşünende ortada iqtisadi tema var Irani qîcıqlandıran mesele budur.Çox gümanki zengezur maqistraliyla açılacaq yeni iqtisadi yol Iranı kenara qoyur ve Iranin itkileri olacaq.Irana qıcıq veren bu meseledi.Yoxsakı heçkim heçkime gülle atan deyil.Tema ne din teması deyil nede  torpaq.Mesele "Money"-di.',
#  'İranın nə istədiyinə politoloqlar cavab verər,amma bir şeyə əminəm ki,İran ölkəmizdəki tulalarına arxayın olub belə rahat danışır.',
#  'İran bizden artiq qorxur.çünki biz güclü dövletik.iran bilir ki,artiq onun serhed qonşusu torpagi işgal altinda olan ezik dövlet deyil ve indi Qarabagi ermeniden alan Azerbaycan 30 il sonrq bir az da dirçelib onlardan Tebrizi,Erdebili,Xorasani teleb edecek.biz artiq onlar üçün potensial tehlükeyik',
# ...

# %%
title = soup.title

# %%
title.text
# Out:
# 'Şəbəkə - 🇮🇷 İran Azərbaycandan nə istəyir? Bizə qarşı niyə... | Facebook'

# %%
paraghs = soup.find_all('p')

# %%
paraghs[0]
# Out:
# <p><span class="by"><span class="bz" style='height: 16px; width: 16px; font-size: 16px; background-image: url("https://static.xx.fbcdn.net/images/emoji.php/v9/tb7/1/16/1f1ee_1f1f7.png")'>🇮🇷</span></span> İran Azərbaycandan nə istəyir? Bizə qarşı niyə qəzəblidirlər?</p>

# %%
# paraghs.find_all(class_ = 'bz')
